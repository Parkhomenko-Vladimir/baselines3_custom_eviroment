# %%
import os
import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy, plot_results
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback

from gym_environment import CustomEnv
from network import CustomCNN

from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
import torch.nn as nn
import torch.nn.functional as F
import torch
from stable_baselines3 import A2C

torch.backends.cudnn.benchmark = True
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Collab callback class

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model_A2C')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        pass
        # Create folder if needed
#         if self.save_path is not None:
#             os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print("Num timesteps: {}".format(self.num_timesteps))
                print("Best mean reward: {:.2f} - Last mean reward per episode: {:.2f}".format(self.best_mean_reward, mean_reward))

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print("Saving new best model to {}".format(self.save_path))
                  self.model.save(self.save_path)

        return True

# %% [markdown]
# # Init logs, model, environment

# %%
log_dir = './saved_models_cont_mult/A2C/'
os.makedirs(log_dir, exist_ok=True)
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

env = CustomEnv(obstacle_turn = False, 
                vizualaze     = False, 
                Total_war     = True,
                )

env = Monitor(env, log_dir)

policy_kwargs = dict(
    features_extractor_class=CustomCNN,
    features_extractor_kwargs=dict(features_dim=518),
    activation_fn=torch.nn.ReLU,
    net_arch = [dict(pi=[1029, 128, 32, 8], vf=[1029, 128, 32, 8])])

model = A2C(policy          = 'MlpPolicy',
            env             = env,
            learning_rate   = 0.0001,
            n_steps         = 2,
            gamma           = 0.99,
            gae_lambda      = 0.95,
            tensorboard_log = "./tensorboard_logs_cont_mult/",
            policy_kwargs   = policy_kwargs,
            verbose         = 0,
            device          = 'cuda',
            use_sde         = True)
# Out:
# /home/tatiana/environments/tatenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float16
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/tatiana/environments/tatenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# # Run learning

# %%
model.learn(total_timesteps=1e6,callback=callback)
# Out:
# /home/tatiana/environments/tatenv/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /home/tatiana/environments/tatenv/lib/python3.8/site-packages/torch/nn/modules/conv.py:439: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  /pytorch/aten/src/ATen/native/Convolution.cpp:660.)
#   return F.conv2d(input, weight, bias, self.stride,
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -74.44
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 2000
# Best mean reward: -74.44 - Last mean reward per episode: -85.95
# Num timesteps: 3000
# Best mean reward: -74.44 - Last mean reward per episode: -55.86
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 4000
# Best mean reward: -55.86 - Last mean reward per episode: -118.29
# Num timesteps: 5000
# Best mean reward: -55.86 - Last mean reward per episode: -118.73
# Num timesteps: 6000
# Best mean reward: -55.86 - Last mean reward per episode: -73.97
# Num timesteps: 7000
# Best mean reward: -55.86 - Last mean reward per episode: -52.08
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 8000
# Best mean reward: -52.08 - Last mean reward per episode: -36.14
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 9000
# Best mean reward: -36.14 - Last mean reward per episode: -60.09
# Num timesteps: 10000
# Best mean reward: -36.14 - Last mean reward per episode: -32.40
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 11000
# Best mean reward: -32.40 - Last mean reward per episode: -46.80
# Num timesteps: 12000
# Best mean reward: -32.40 - Last mean reward per episode: -80.31
# Num timesteps: 13000
# Best mean reward: -32.40 - Last mean reward per episode: -111.05
# Num timesteps: 14000
# Best mean reward: -32.40 - Last mean reward per episode: -122.42
# Num timesteps: 15000
# Best mean reward: -32.40 - Last mean reward per episode: -130.93
# Num timesteps: 16000
# Best mean reward: -32.40 - Last mean reward per episode: -135.03
# Num timesteps: 17000
# Best mean reward: -32.40 - Last mean reward per episode: -123.97
# Num timesteps: 18000
# Best mean reward: -32.40 - Last mean reward per episode: -120.00
# Num timesteps: 19000
# Best mean reward: -32.40 - Last mean reward per episode: -125.06
# Num timesteps: 20000
# Best mean reward: -32.40 - Last mean reward per episode: -134.98
# Num timesteps: 21000
# Best mean reward: -32.40 - Last mean reward per episode: -115.38
# Num timesteps: 22000
# Best mean reward: -32.40 - Last mean reward per episode: -113.87
# Num timesteps: 23000
# Best mean reward: -32.40 - Last mean reward per episode: -111.14
# Num timesteps: 24000
# Best mean reward: -32.40 - Last mean reward per episode: -104.96
# Num timesteps: 25000
# Best mean reward: -32.40 - Last mean reward per episode: -100.87
# Num timesteps: 26000
# Best mean reward: -32.40 - Last mean reward per episode: -102.38
# Num timesteps: 27000
# Best mean reward: -32.40 - Last mean reward per episode: -101.21
# Num timesteps: 28000
# Best mean reward: -32.40 - Last mean reward per episode: -98.84
# Num timesteps: 29000
# Best mean reward: -32.40 - Last mean reward per episode: -97.75
# Num timesteps: 30000
# Best mean reward: -32.40 - Last mean reward per episode: -114.45
# Num timesteps: 31000
# Best mean reward: -32.40 - Last mean reward per episode: -121.28
# Num timesteps: 32000
# Best mean reward: -32.40 - Last mean reward per episode: -111.73
# Num timesteps: 33000
# Best mean reward: -32.40 - Last mean reward per episode: -142.28
# Num timesteps: 34000
# Best mean reward: -32.40 - Last mean reward per episode: -142.43
# Num timesteps: 35000
# Best mean reward: -32.40 - Last mean reward per episode: -151.74
# Num timesteps: 36000
# Best mean reward: -32.40 - Last mean reward per episode: -148.48
# Num timesteps: 37000
# Best mean reward: -32.40 - Last mean reward per episode: -163.37
# Num timesteps: 38000
# Best mean reward: -32.40 - Last mean reward per episode: -149.44
# Num timesteps: 39000
# Best mean reward: -32.40 - Last mean reward per episode: -147.31
# Num timesteps: 40000
# Best mean reward: -32.40 - Last mean reward per episode: -134.05
# Num timesteps: 41000
# Best mean reward: -32.40 - Last mean reward per episode: -136.68
# Num timesteps: 42000
# Best mean reward: -32.40 - Last mean reward per episode: -141.70
# Num timesteps: 43000
# Best mean reward: -32.40 - Last mean reward per episode: -142.11
# Num timesteps: 44000
# Best mean reward: -32.40 - Last mean reward per episode: -131.03
# Num timesteps: 45000
# Best mean reward: -32.40 - Last mean reward per episode: -131.03
# Num timesteps: 46000
# Best mean reward: -32.40 - Last mean reward per episode: -144.11
# Num timesteps: 47000
# Best mean reward: -32.40 - Last mean reward per episode: -150.45
# Num timesteps: 48000
# Best mean reward: -32.40 - Last mean reward per episode: -138.06
# Num timesteps: 49000
# Best mean reward: -32.40 - Last mean reward per episode: -127.98
# Num timesteps: 50000
# Best mean reward: -32.40 - Last mean reward per episode: -141.57
# Num timesteps: 51000
# Best mean reward: -32.40 - Last mean reward per episode: -125.03
# Num timesteps: 52000
# Best mean reward: -32.40 - Last mean reward per episode: -143.37
# Num timesteps: 53000
# Best mean reward: -32.40 - Last mean reward per episode: -153.34
# Num timesteps: 54000
# Best mean reward: -32.40 - Last mean reward per episode: -151.04
# Num timesteps: 55000
# Best mean reward: -32.40 - Last mean reward per episode: -155.91
# Num timesteps: 56000
# Best mean reward: -32.40 - Last mean reward per episode: -155.18
# Num timesteps: 57000
# Best mean reward: -32.40 - Last mean reward per episode: -145.15
# Num timesteps: 58000
# Best mean reward: -32.40 - Last mean reward per episode: -140.62
# Num timesteps: 59000
# Best mean reward: -32.40 - Last mean reward per episode: -141.38
# Num timesteps: 60000
# Best mean reward: -32.40 - Last mean reward per episode: -137.14
# Num timesteps: 61000
# Best mean reward: -32.40 - Last mean reward per episode: -111.10
# Num timesteps: 62000
# Best mean reward: -32.40 - Last mean reward per episode: -89.12
# Num timesteps: 63000
# Best mean reward: -32.40 - Last mean reward per episode: -52.37
# Num timesteps: 64000
# Best mean reward: -32.40 - Last mean reward per episode: -55.68
# Num timesteps: 65000
# Best mean reward: -32.40 - Last mean reward per episode: -45.33
# Num timesteps: 66000
# Best mean reward: -32.40 - Last mean reward per episode: -31.13
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 67000
# Best mean reward: -31.13 - Last mean reward per episode: -31.13
# Num timesteps: 68000
# Best mean reward: -31.13 - Last mean reward per episode: -39.35
# Num timesteps: 69000
# Best mean reward: -31.13 - Last mean reward per episode: -32.68
# Num timesteps: 70000
# Best mean reward: -31.13 - Last mean reward per episode: -39.67
# Num timesteps: 71000
# Best mean reward: -31.13 - Last mean reward per episode: -32.55
# Num timesteps: 72000
# Best mean reward: -31.13 - Last mean reward per episode: -18.36
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 73000
# Best mean reward: -18.36 - Last mean reward per episode: 0.97
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 74000
# Best mean reward: 0.97 - Last mean reward per episode: 6.39
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 75000
# Best mean reward: 6.39 - Last mean reward per episode: 29.85
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 76000
# Best mean reward: 29.85 - Last mean reward per episode: 31.91
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 77000
# Best mean reward: 31.91 - Last mean reward per episode: 50.68
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 78000
# Best mean reward: 50.68 - Last mean reward per episode: 57.59
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 79000
# Best mean reward: 57.59 - Last mean reward per episode: 56.10
# Num timesteps: 80000
# Best mean reward: 57.59 - Last mean reward per episode: 74.31
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 81000
# Best mean reward: 74.31 - Last mean reward per episode: 74.31
# Num timesteps: 82000
# Best mean reward: 74.31 - Last mean reward per episode: 68.59
# Num timesteps: 83000
# Best mean reward: 74.31 - Last mean reward per episode: 78.51
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 84000
# Best mean reward: 78.51 - Last mean reward per episode: 75.67
# Num timesteps: 85000
# Best mean reward: 78.51 - Last mean reward per episode: 72.71
# Num timesteps: 86000
# Best mean reward: 78.51 - Last mean reward per episode: 72.71
# Num timesteps: 87000
# Best mean reward: 78.51 - Last mean reward per episode: 73.85
# Num timesteps: 88000
# Best mean reward: 78.51 - Last mean reward per episode: 73.85
# Num timesteps: 89000
# Best mean reward: 78.51 - Last mean reward per episode: 71.64
# Num timesteps: 90000
# Best mean reward: 78.51 - Last mean reward per episode: 62.89
# Num timesteps: 91000
# Best mean reward: 78.51 - Last mean reward per episode: 70.96
# Num timesteps: 92000
# Best mean reward: 78.51 - Last mean reward per episode: 68.86
# Num timesteps: 93000
# Best mean reward: 78.51 - Last mean reward per episode: 72.54
# Num timesteps: 94000
# Best mean reward: 78.51 - Last mean reward per episode: 72.54
# Num timesteps: 95000
# Best mean reward: 78.51 - Last mean reward per episode: 79.94
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 96000
# Best mean reward: 79.94 - Last mean reward per episode: 85.22
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 97000
# Best mean reward: 85.22 - Last mean reward per episode: 99.55
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 98000
# Best mean reward: 99.55 - Last mean reward per episode: 117.21
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 99000
# Best mean reward: 117.21 - Last mean reward per episode: 123.30
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 100000
# Best mean reward: 123.30 - Last mean reward per episode: 128.53
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 101000
# Best mean reward: 128.53 - Last mean reward per episode: 122.14
# Num timesteps: 102000
# Best mean reward: 128.53 - Last mean reward per episode: 122.51
# Num timesteps: 103000
# Best mean reward: 128.53 - Last mean reward per episode: 132.70
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 104000
# Best mean reward: 132.70 - Last mean reward per episode: 132.70
# Num timesteps: 105000
# Best mean reward: 132.70 - Last mean reward per episode: 135.46
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 106000
# Best mean reward: 135.46 - Last mean reward per episode: 136.40
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 107000
# Best mean reward: 136.40 - Last mean reward per episode: 130.41
# Num timesteps: 108000
# Best mean reward: 136.40 - Last mean reward per episode: 126.25
# Num timesteps: 109000
# Best mean reward: 136.40 - Last mean reward per episode: 121.37
# Num timesteps: 110000
# Best mean reward: 136.40 - Last mean reward per episode: 121.37
# Num timesteps: 111000
# Best mean reward: 136.40 - Last mean reward per episode: 116.97
# Num timesteps: 112000
# Best mean reward: 136.40 - Last mean reward per episode: 116.97
# Num timesteps: 113000
# Best mean reward: 136.40 - Last mean reward per episode: 111.29
# Num timesteps: 114000
# Best mean reward: 136.40 - Last mean reward per episode: 120.61
# Num timesteps: 115000
# Best mean reward: 136.40 - Last mean reward per episode: 117.38
# Num timesteps: 116000
# Best mean reward: 136.40 - Last mean reward per episode: 112.22
# Num timesteps: 117000
# Best mean reward: 136.40 - Last mean reward per episode: 113.91
# Num timesteps: 118000
# Best mean reward: 136.40 - Last mean reward per episode: 116.36
# Num timesteps: 119000
# Best mean reward: 136.40 - Last mean reward per episode: 119.84
# Num timesteps: 120000
# Best mean reward: 136.40 - Last mean reward per episode: 119.84
# Num timesteps: 121000
# Best mean reward: 136.40 - Last mean reward per episode: 106.68
# Num timesteps: 122000
# Best mean reward: 136.40 - Last mean reward per episode: 117.54
# Num timesteps: 123000
# Best mean reward: 136.40 - Last mean reward per episode: 111.54
# Num timesteps: 124000
# Best mean reward: 136.40 - Last mean reward per episode: 119.54
# Num timesteps: 125000
# Best mean reward: 136.40 - Last mean reward per episode: 122.68
# Num timesteps: 126000
# Best mean reward: 136.40 - Last mean reward per episode: 124.30
# Num timesteps: 127000
# Best mean reward: 136.40 - Last mean reward per episode: 122.34
# Num timesteps: 128000
# Best mean reward: 136.40 - Last mean reward per episode: 119.30
# Num timesteps: 129000
# Best mean reward: 136.40 - Last mean reward per episode: 119.30
# Num timesteps: 130000
# Best mean reward: 136.40 - Last mean reward per episode: 119.10
# Num timesteps: 131000
# Best mean reward: 136.40 - Last mean reward per episode: 128.71
# Num timesteps: 132000
# Best mean reward: 136.40 - Last mean reward per episode: 133.00
# Num timesteps: 133000
# Best mean reward: 136.40 - Last mean reward per episode: 148.94
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 134000
# Best mean reward: 148.94 - Last mean reward per episode: 141.78
# Num timesteps: 135000
# Best mean reward: 148.94 - Last mean reward per episode: 154.35
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 136000
# Best mean reward: 154.35 - Last mean reward per episode: 154.08
# Num timesteps: 137000
# Best mean reward: 154.35 - Last mean reward per episode: 154.08
# Num timesteps: 138000
# Best mean reward: 154.35 - Last mean reward per episode: 161.33
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 139000
# Best mean reward: 161.33 - Last mean reward per episode: 161.33
# Num timesteps: 140000
# Best mean reward: 161.33 - Last mean reward per episode: 154.62
# Num timesteps: 141000
# Best mean reward: 161.33 - Last mean reward per episode: 151.08
# Num timesteps: 142000
# Best mean reward: 161.33 - Last mean reward per episode: 145.53
# Num timesteps: 143000
# Best mean reward: 161.33 - Last mean reward per episode: 145.26
# Num timesteps: 144000
# Best mean reward: 161.33 - Last mean reward per episode: 165.58
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 145000
# Best mean reward: 165.58 - Last mean reward per episode: 165.58
# Num timesteps: 146000
# Best mean reward: 165.58 - Last mean reward per episode: 184.42
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 147000
# Best mean reward: 184.42 - Last mean reward per episode: 197.44
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 148000
# Best mean reward: 197.44 - Last mean reward per episode: 215.78
# Saving new best model to ./saved_models_cont_mult/A2C/best_model_A2C
# Num timesteps: 149000
# Best mean reward: 215.78 - Last mean reward per episode: 213.14
# Num timesteps: 150000
# Best mean reward: 215.78 - Last mean reward per episode: 211.50
# Num timesteps: 151000
# Best mean reward: 215.78 - Last mean reward per episode: 209.55
# Num timesteps: 152000
# Best mean reward: 215.78 - Last mean reward per episode: 208.76
# Num timesteps: 153000
# Best mean reward: 215.78 - Last mean reward per episode: 208.76
# Num timesteps: 154000
# Best mean reward: 215.78 - Last mean reward per episode: 201.07
# Num timesteps: 155000
# Best mean reward: 215.78 - Last mean reward per episode: 200.52
# Num timesteps: 156000
# Best mean reward: 215.78 - Last mean reward per episode: 193.26
# Num timesteps: 157000
# Best mean reward: 215.78 - Last mean reward per episode: 189.38
# Num timesteps: 158000
# Best mean reward: 215.78 - Last mean reward per episode: 189.38
# Num timesteps: 159000
# Best mean reward: 215.78 - Last mean reward per episode: 190.48
# Num timesteps: 160000
# Best mean reward: 215.78 - Last mean reward per episode: 189.06
# Num timesteps: 161000
# Best mean reward: 215.78 - Last mean reward per episode: 189.06
# Num timesteps: 162000
# Best mean reward: 215.78 - Last mean reward per episode: 176.73
# Num timesteps: 163000
# Best mean reward: 215.78 - Last mean reward per episode: 174.34
# Num timesteps: 164000
# Best mean reward: 215.78 - Last mean reward per episode: 172.52
# Num timesteps: 165000
# Best mean reward: 215.78 - Last mean reward per episode: 172.52
# Num timesteps: 166000
# Best mean reward: 215.78 - Last mean reward per episode: 166.32
# Num timesteps: 167000
# Best mean reward: 215.78 - Last mean reward per episode: 161.26
# Num timesteps: 168000
# Best mean reward: 215.78 - Last mean reward per episode: 161.26
# Num timesteps: 169000
# Best mean reward: 215.78 - Last mean reward per episode: 165.56
# Num timesteps: 170000
# Best mean reward: 215.78 - Last mean reward per episode: 162.39
# Num timesteps: 171000
# Best mean reward: 215.78 - Last mean reward per episode: 162.39
# Num timesteps: 172000
# Best mean reward: 215.78 - Last mean reward per episode: 164.13
# Num timesteps: 173000
# Best mean reward: 215.78 - Last mean reward per episode: 157.55
# Num timesteps: 174000
# Best mean reward: 215.78 - Last mean reward per episode: 154.56
# Num timesteps: 175000
# Best mean reward: 215.78 - Last mean reward per episode: 154.56
# Num timesteps: 176000
# Best mean reward: 215.78 - Last mean reward per episode: 149.06
# Num timesteps: 177000
# Best mean reward: 215.78 - Last mean reward per episode: 141.61
# Num timesteps: 178000
# Best mean reward: 215.78 - Last mean reward per episode: 141.61
# Num timesteps: 179000
# Best mean reward: 215.78 - Last mean reward per episode: 144.26
# Num timesteps: 180000
# Best mean reward: 215.78 - Last mean reward per episode: 139.31
# Num timesteps: 181000
# Best mean reward: 215.78 - Last mean reward per episode: 139.31
# Num timesteps: 182000
# Best mean reward: 215.78 - Last mean reward per episode: 137.79
# Num timesteps: 183000
# Best mean reward: 215.78 - Last mean reward per episode: 142.47
# Num timesteps: 184000
# Best mean reward: 215.78 - Last mean reward per episode: 142.47
# Num timesteps: 185000
# Best mean reward: 215.78 - Last mean reward per episode: 142.05
# Num timesteps: 186000
# Best mean reward: 215.78 - Last mean reward per episode: 138.51
# Num timesteps: 187000
# Best mean reward: 215.78 - Last mean reward per episode: 128.65
# Num timesteps: 188000
# Best mean reward: 215.78 - Last mean reward per episode: 127.43
# Num timesteps: 189000
# Best mean reward: 215.78 - Last mean reward per episode: 122.58
# Num timesteps: 190000
# Best mean reward: 215.78 - Last mean reward per episode: 107.91
# Num timesteps: 191000
# Best mean reward: 215.78 - Last mean reward per episode: 107.91
# Num timesteps: 192000
# Best mean reward: 215.78 - Last mean reward per episode: 106.66
# Num timesteps: 193000
# Best mean reward: 215.78 - Last mean reward per episode: 108.44
# Num timesteps: 194000
# Best mean reward: 215.78 - Last mean reward per episode: 108.44
# Num timesteps: 195000
# Best mean reward: 215.78 - Last mean reward per episode: 108.46
# Num timesteps: 196000
# Best mean reward: 215.78 - Last mean reward per episode: 96.21
# Num timesteps: 197000
# Best mean reward: 215.78 - Last mean reward per episode: 96.21
# Num timesteps: 198000
# Best mean reward: 215.78 - Last mean reward per episode: 99.55
# Num timesteps: 199000
# Best mean reward: 215.78 - Last mean reward per episode: 93.50
# Num timesteps: 200000
# Best mean reward: 215.78 - Last mean reward per episode: 93.50
# Num timesteps: 201000
# Best mean reward: 215.78 - Last mean reward per episode: 90.58
# Num timesteps: 202000
# Best mean reward: 215.78 - Last mean reward per episode: 91.60
# Num timesteps: 203000
# Best mean reward: 215.78 - Last mean reward per episode: 91.60
# Num timesteps: 204000
# Best mean reward: 215.78 - Last mean reward per episode: 88.99
# Num timesteps: 205000
# Best mean reward: 215.78 - Last mean reward per episode: 83.36
# Num timesteps: 206000
# Best mean reward: 215.78 - Last mean reward per episode: 83.36
# Num timesteps: 207000
# Best mean reward: 215.78 - Last mean reward per episode: 87.65
# Num timesteps: 208000
# Best mean reward: 215.78 - Last mean reward per episode: 87.46
# Num timesteps: 209000
# Best mean reward: 215.78 - Last mean reward per episode: 75.49
# Num timesteps: 210000
# Best mean reward: 215.78 - Last mean reward per episode: 75.49
# Num timesteps: 211000
# Best mean reward: 215.78 - Last mean reward per episode: 68.89
# Num timesteps: 212000
# Best mean reward: 215.78 - Last mean reward per episode: 62.02
# Num timesteps: 213000
# Best mean reward: 215.78 - Last mean reward per episode: 62.02
# Num timesteps: 214000
# Best mean reward: 215.78 - Last mean reward per episode: 59.31
# Num timesteps: 215000
# Best mean reward: 215.78 - Last mean reward per episode: 54.16
# Num timesteps: 216000
# Best mean reward: 215.78 - Last mean reward per episode: 54.16
# Num timesteps: 217000
# Best mean reward: 215.78 - Last mean reward per episode: 52.34
# Num timesteps: 218000
# Best mean reward: 215.78 - Last mean reward per episode: 52.66
# Num timesteps: 219000
# Best mean reward: 215.78 - Last mean reward per episode: 52.66
# Num timesteps: 220000
# Best mean reward: 215.78 - Last mean reward per episode: 45.94
# Num timesteps: 221000
# Best mean reward: 215.78 - Last mean reward per episode: 40.08
# Num timesteps: 222000
# Best mean reward: 215.78 - Last mean reward per episode: 36.09
# Num timesteps: 223000
# Best mean reward: 215.78 - Last mean reward per episode: 36.09
# Num timesteps: 224000
# Best mean reward: 215.78 - Last mean reward per episode: 27.96
# Num timesteps: 225000
# Best mean reward: 215.78 - Last mean reward per episode: 21.09
# Num timesteps: 226000
# Best mean reward: 215.78 - Last mean reward per episode: 21.09
# Num timesteps: 227000
# Best mean reward: 215.78 - Last mean reward per episode: 20.32
# Num timesteps: 228000
# Best mean reward: 215.78 - Last mean reward per episode: 14.87
# Num timesteps: 229000
# Best mean reward: 215.78 - Last mean reward per episode: 14.87
# Num timesteps: 230000
# Best mean reward: 215.78 - Last mean reward per episode: 10.41
# Num timesteps: 231000
# Best mean reward: 215.78 - Last mean reward per episode: 4.08
# Num timesteps: 232000
# Best mean reward: 215.78 - Last mean reward per episode: 4.08
# Num timesteps: 233000
# Best mean reward: 215.78 - Last mean reward per episode: -0.14
# Num timesteps: 234000
# Best mean reward: 215.78 - Last mean reward per episode: -5.10
# Num timesteps: 235000
# Best mean reward: 215.78 - Last mean reward per episode: -5.10
# Num timesteps: 236000
# Best mean reward: 215.78 - Last mean reward per episode: -9.40
# Num timesteps: 237000
# Best mean reward: 215.78 - Last mean reward per episode: -16.19
# Num timesteps: 238000
# Best mean reward: 215.78 - Last mean reward per episode: -16.11
# Num timesteps: 239000
# Best mean reward: 215.78 - Last mean reward per episode: -16.15
# Num timesteps: 240000
# Best mean reward: 215.78 - Last mean reward per episode: -16.15
# Num timesteps: 241000
# Best mean reward: 215.78 - Last mean reward per episode: -23.11
# Num timesteps: 242000
# Best mean reward: 215.78 - Last mean reward per episode: -23.11
# Num timesteps: 243000
# Best mean reward: 215.78 - Last mean reward per episode: -25.51
# Num timesteps: 244000
# Best mean reward: 215.78 - Last mean reward per episode: -30.65
# Num timesteps: 245000
# Best mean reward: 215.78 - Last mean reward per episode: -30.65
# Num timesteps: 246000
# Best mean reward: 215.78 - Last mean reward per episode: -33.63
# Num timesteps: 247000
# Best mean reward: 215.78 - Last mean reward per episode: -40.24
# Num timesteps: 248000
# Best mean reward: 215.78 - Last mean reward per episode: -40.24
# Num timesteps: 249000
# Best mean reward: 215.78 - Last mean reward per episode: -57.11
# Num timesteps: 250000
# Best mean reward: 215.78 - Last mean reward per episode: -56.55
# Num timesteps: 251000
# Best mean reward: 215.78 - Last mean reward per episode: -58.65
# Num timesteps: 252000
# Best mean reward: 215.78 - Last mean reward per episode: -58.65
# Num timesteps: 253000
# Best mean reward: 215.78 - Last mean reward per episode: -59.89
# Num timesteps: 254000
# Best mean reward: 215.78 - Last mean reward per episode: -63.84
# Num timesteps: 255000
# Best mean reward: 215.78 - Last mean reward per episode: -63.84
# Num timesteps: 256000
# Best mean reward: 215.78 - Last mean reward per episode: -56.22
# Num timesteps: 257000
# Best mean reward: 215.78 - Last mean reward per episode: -65.40
# Num timesteps: 258000
# Best mean reward: 215.78 - Last mean reward per episode: -72.74
# Num timesteps: 259000
# Best mean reward: 215.78 - Last mean reward per episode: -78.33
# Num timesteps: 260000
# Best mean reward: 215.78 - Last mean reward per episode: -78.33
# Num timesteps: 261000
# Best mean reward: 215.78 - Last mean reward per episode: -84.17
# Num timesteps: 262000
# Best mean reward: 215.78 - Last mean reward per episode: -92.41
# Num timesteps: 263000
# Best mean reward: 215.78 - Last mean reward per episode: -92.41
# Num timesteps: 264000
# Best mean reward: 215.78 - Last mean reward per episode: -98.08
# Num timesteps: 265000
# Best mean reward: 215.78 - Last mean reward per episode: -104.13
# Num timesteps: 266000
# Best mean reward: 215.78 - Last mean reward per episode: -104.13
# Num timesteps: 267000
# Best mean reward: 215.78 - Last mean reward per episode: -113.87
# Num timesteps: 268000
# Best mean reward: 215.78 - Last mean reward per episode: -117.01
# Num timesteps: 269000
# Best mean reward: 215.78 - Last mean reward per episode: -117.01
# Num timesteps: 270000
# Best mean reward: 215.78 - Last mean reward per episode: -124.88
# Num timesteps: 271000
# Best mean reward: 215.78 - Last mean reward per episode: -129.46
# Num timesteps: 272000
# Best mean reward: 215.78 - Last mean reward per episode: -138.59
# Num timesteps: 273000
# Best mean reward: 215.78 - Last mean reward per episode: -138.59
# Num timesteps: 274000
# Best mean reward: 215.78 - Last mean reward per episode: -144.31
# Num timesteps: 275000
# Best mean reward: 215.78 - Last mean reward per episode: -148.79
# Num timesteps: 276000
# Best mean reward: 215.78 - Last mean reward per episode: -148.79
# Num timesteps: 277000
# Best mean reward: 215.78 - Last mean reward per episode: -143.66
# Num timesteps: 278000
# Best mean reward: 215.78 - Last mean reward per episode: -140.28
# Num timesteps: 279000
# Best mean reward: 215.78 - Last mean reward per episode: -140.28
# Num timesteps: 280000
# Best mean reward: 215.78 - Last mean reward per episode: -143.58
# Num timesteps: 281000
# Best mean reward: 215.78 - Last mean reward per episode: -142.26
# Num timesteps: 282000
# Best mean reward: 215.78 - Last mean reward per episode: -141.08
# Num timesteps: 283000
# Best mean reward: 215.78 - Last mean reward per episode: -138.83
# Num timesteps: 284000
# Best mean reward: 215.78 - Last mean reward per episode: -133.50
# Num timesteps: 285000
# Best mean reward: 215.78 - Last mean reward per episode: -133.50
# Num timesteps: 286000
# Best mean reward: 215.78 - Last mean reward per episode: -129.87
# Num timesteps: 287000
# Best mean reward: 215.78 - Last mean reward per episode: -127.21
# Num timesteps: 288000
# Best mean reward: 215.78 - Last mean reward per episode: -127.21
# Num timesteps: 289000
# Best mean reward: 215.78 - Last mean reward per episode: -132.09
# Num timesteps: 290000
# Best mean reward: 215.78 - Last mean reward per episode: -129.70
# Num timesteps: 291000
# Best mean reward: 215.78 - Last mean reward per episode: -135.19
# Num timesteps: 292000
# Best mean reward: 215.78 - Last mean reward per episode: -135.19
# Num timesteps: 293000
# Best mean reward: 215.78 - Last mean reward per episode: -140.06
# Num timesteps: 294000
# Best mean reward: 215.78 - Last mean reward per episode: -143.66
# Num timesteps: 295000
# Best mean reward: 215.78 - Last mean reward per episode: -143.66
# Num timesteps: 296000
# Best mean reward: 215.78 - Last mean reward per episode: -140.88
# Num timesteps: 297000
# Best mean reward: 215.78 - Last mean reward per episode: -148.14
# Num timesteps: 298000
# Best mean reward: 215.78 - Last mean reward per episode: -148.14
# Num timesteps: 299000
# Best mean reward: 215.78 - Last mean reward per episode: -153.02
# Num timesteps: 300000
# Best mean reward: 215.78 - Last mean reward per episode: -150.44
# Num timesteps: 301000
# Best mean reward: 215.78 - Last mean reward per episode: -150.44
# Num timesteps: 302000
# Best mean reward: 215.78 - Last mean reward per episode: -149.86
# Num timesteps: 303000
# Best mean reward: 215.78 - Last mean reward per episode: -150.93
# Num timesteps: 304000
# Best mean reward: 215.78 - Last mean reward per episode: -150.93
# Num timesteps: 305000
# Best mean reward: 215.78 - Last mean reward per episode: -156.57
# Num timesteps: 306000
# Best mean reward: 215.78 - Last mean reward per episode: -153.03
# Num timesteps: 307000
# Best mean reward: 215.78 - Last mean reward per episode: -152.44
# Num timesteps: 308000
# Best mean reward: 215.78 - Last mean reward per episode: -152.44
# Num timesteps: 309000
# Best mean reward: 215.78 - Last mean reward per episode: -154.31
# Num timesteps: 310000
# Best mean reward: 215.78 - Last mean reward per episode: -154.48
# Num timesteps: 311000
# Best mean reward: 215.78 - Last mean reward per episode: -154.48
# Num timesteps: 312000
# Best mean reward: 215.78 - Last mean reward per episode: -147.53
# Num timesteps: 313000
# Best mean reward: 215.78 - Last mean reward per episode: -147.99
# Num timesteps: 314000
# Best mean reward: 215.78 - Last mean reward per episode: -148.31
# Num timesteps: 315000
# Best mean reward: 215.78 - Last mean reward per episode: -154.07
# Num timesteps: 316000
# Best mean reward: 215.78 - Last mean reward per episode: -157.52
# Num timesteps: 317000
# Best mean reward: 215.78 - Last mean reward per episode: -157.52
# Num timesteps: 318000
# Best mean reward: 215.78 - Last mean reward per episode: -153.95
# Num timesteps: 319000
# Best mean reward: 215.78 - Last mean reward per episode: -158.05
# Num timesteps: 320000
# Best mean reward: 215.78 - Last mean reward per episode: -158.05
# Num timesteps: 321000
# Best mean reward: 215.78 - Last mean reward per episode: -154.11
# Num timesteps: 322000
# Best mean reward: 215.78 - Last mean reward per episode: -151.13
# Num timesteps: 323000
# Best mean reward: 215.78 - Last mean reward per episode: -151.13
# Num timesteps: 324000
# Best mean reward: 215.78 - Last mean reward per episode: -149.60
# Num timesteps: 325000
# Best mean reward: 215.78 - Last mean reward per episode: -146.52
# Num timesteps: 326000
# Best mean reward: 215.78 - Last mean reward per episode: -146.52
# Num timesteps: 327000
# Best mean reward: 215.78 - Last mean reward per episode: -145.20
# Num timesteps: 328000
# Best mean reward: 215.78 - Last mean reward per episode: -145.06
# Num timesteps: 329000
# Best mean reward: 215.78 - Last mean reward per episode: -145.06
# Num timesteps: 330000
# Best mean reward: 215.78 - Last mean reward per episode: -150.68
# Num timesteps: 331000
# Best mean reward: 215.78 - Last mean reward per episode: -150.68
# Num timesteps: 332000
# Best mean reward: 215.78 - Last mean reward per episode: -155.04
# Num timesteps: 333000
# Best mean reward: 215.78 - Last mean reward per episode: -153.68
# Num timesteps: 334000
# Best mean reward: 215.78 - Last mean reward per episode: -153.68
# Num timesteps: 335000
# Best mean reward: 215.78 - Last mean reward per episode: -153.56
# Num timesteps: 336000
# Best mean reward: 215.78 - Last mean reward per episode: -155.97
# Num timesteps: 337000
# Best mean reward: 215.78 - Last mean reward per episode: -155.97
# Num timesteps: 338000
# Best mean reward: 215.78 - Last mean reward per episode: -152.22
# Num timesteps: 339000
# Best mean reward: 215.78 - Last mean reward per episode: -152.22
# Num timesteps: 340000
# Best mean reward: 215.78 - Last mean reward per episode: -152.58
# Num timesteps: 341000
# Best mean reward: 215.78 - Last mean reward per episode: -149.10
# Num timesteps: 342000
# Best mean reward: 215.78 - Last mean reward per episode: -149.10
# Num timesteps: 343000
# Best mean reward: 215.78 - Last mean reward per episode: -153.35
# Num timesteps: 344000
# Best mean reward: 215.78 - Last mean reward per episode: -157.58
# Num timesteps: 345000
# Best mean reward: 215.78 - Last mean reward per episode: -157.58
# Num timesteps: 346000
# Best mean reward: 215.78 - Last mean reward per episode: -152.53
# Num timesteps: 347000
# Best mean reward: 215.78 - Last mean reward per episode: -151.34
# Num timesteps: 348000
# Best mean reward: 215.78 - Last mean reward per episode: -151.34
# Num timesteps: 349000
# Best mean reward: 215.78 - Last mean reward per episode: -152.81
# Num timesteps: 350000
# Best mean reward: 215.78 - Last mean reward per episode: -157.37
# Num timesteps: 351000
# Best mean reward: 215.78 - Last mean reward per episode: -158.00
# Num timesteps: 352000
# Best mean reward: 215.78 - Last mean reward per episode: -158.00
# Num timesteps: 353000
# Best mean reward: 215.78 - Last mean reward per episode: -163.20
# Num timesteps: 354000
# Best mean reward: 215.78 - Last mean reward per episode: -165.65
# Num timesteps: 355000
# Best mean reward: 215.78 - Last mean reward per episode: -169.50
# Num timesteps: 356000
# Best mean reward: 215.78 - Last mean reward per episode: -170.32
# Num timesteps: 357000
# Best mean reward: 215.78 - Last mean reward per episode: -170.32
# Num timesteps: 358000
# Best mean reward: 215.78 - Last mean reward per episode: -165.19
# Num timesteps: 359000
# Best mean reward: 215.78 - Last mean reward per episode: -159.22
# Num timesteps: 360000
# Best mean reward: 215.78 - Last mean reward per episode: -159.22
# Num timesteps: 361000
# Best mean reward: 215.78 - Last mean reward per episode: -157.46
# Num timesteps: 362000
# Best mean reward: 215.78 - Last mean reward per episode: -153.88
# Num timesteps: 363000
# Best mean reward: 215.78 - Last mean reward per episode: -153.88
# Num timesteps: 364000
# Best mean reward: 215.78 - Last mean reward per episode: -156.36
# Num timesteps: 365000
# Best mean reward: 215.78 - Last mean reward per episode: -152.70
# Num timesteps: 366000
# Best mean reward: 215.78 - Last mean reward per episode: -156.79
# Num timesteps: 367000
# Best mean reward: 215.78 - Last mean reward per episode: -156.79
# Num timesteps: 368000
# Best mean reward: 215.78 - Last mean reward per episode: -158.88
# Num timesteps: 369000
# Best mean reward: 215.78 - Last mean reward per episode: -159.94
# Num timesteps: 370000
# Best mean reward: 215.78 - Last mean reward per episode: -164.33
# Num timesteps: 371000
# Best mean reward: 215.78 - Last mean reward per episode: -164.33
# Num timesteps: 372000
# Best mean reward: 215.78 - Last mean reward per episode: -164.09
# Num timesteps: 373000
# Best mean reward: 215.78 - Last mean reward per episode: -165.19
# Num timesteps: 374000
# Best mean reward: 215.78 - Last mean reward per episode: -164.09
# Num timesteps: 375000
# Best mean reward: 215.78 - Last mean reward per episode: -167.55
# Num timesteps: 376000
# Best mean reward: 215.78 - Last mean reward per episode: -167.66
# Num timesteps: 377000
# Best mean reward: 215.78 - Last mean reward per episode: -170.50
# Num timesteps: 378000
# Best mean reward: 215.78 - Last mean reward per episode: -169.87
# Num timesteps: 379000
# Best mean reward: 215.78 - Last mean reward per episode: -169.87
# Num timesteps: 380000
# Best mean reward: 215.78 - Last mean reward per episode: -171.66
# Num timesteps: 381000
# Best mean reward: 215.78 - Last mean reward per episode: -169.50
# Num timesteps: 382000
# Best mean reward: 215.78 - Last mean reward per episode: -169.50
# Num timesteps: 383000
# Best mean reward: 215.78 - Last mean reward per episode: -166.06
# Num timesteps: 384000
# Best mean reward: 215.78 - Last mean reward per episode: -162.81
# Num timesteps: 385000
# Best mean reward: 215.78 - Last mean reward per episode: -164.30
# Num timesteps: 386000
# Best mean reward: 215.78 - Last mean reward per episode: -165.72
# Num timesteps: 387000
# Best mean reward: 215.78 - Last mean reward per episode: -165.72
# Num timesteps: 388000
# Best mean reward: 215.78 - Last mean reward per episode: -167.26
# Num timesteps: 389000
# Best mean reward: 215.78 - Last mean reward per episode: -162.01
# Num timesteps: 390000
# Best mean reward: 215.78 - Last mean reward per episode: -166.00
# Num timesteps: 391000
# Best mean reward: 215.78 - Last mean reward per episode: -165.07
# Num timesteps: 392000
# Best mean reward: 215.78 - Last mean reward per episode: -163.55
# Num timesteps: 393000
# Best mean reward: 215.78 - Last mean reward per episode: -163.55
# Num timesteps: 394000
# Best mean reward: 215.78 - Last mean reward per episode: -161.97
# Num timesteps: 395000
# Best mean reward: 215.78 - Last mean reward per episode: -161.97
# Num timesteps: 396000
# Best mean reward: 215.78 - Last mean reward per episode: -162.19
# Num timesteps: 397000
# Best mean reward: 215.78 - Last mean reward per episode: -158.71
# Num timesteps: 398000
# Best mean reward: 215.78 - Last mean reward per episode: -158.71
# Num timesteps: 399000
# Best mean reward: 215.78 - Last mean reward per episode: -159.51
# Num timesteps: 400000
# Best mean reward: 215.78 - Last mean reward per episode: -160.61
# Num timesteps: 401000
# Best mean reward: 215.78 - Last mean reward per episode: -160.61
# Num timesteps: 402000
# Best mean reward: 215.78 - Last mean reward per episode: -163.37
# Num timesteps: 403000
# Best mean reward: 215.78 - Last mean reward per episode: -167.96
# Num timesteps: 404000
# Best mean reward: 215.78 - Last mean reward per episode: -167.96
# Num timesteps: 405000
# Best mean reward: 215.78 - Last mean reward per episode: -171.18
# Num timesteps: 406000
# Best mean reward: 215.78 - Last mean reward per episode: -166.95
# Num timesteps: 407000
# Best mean reward: 215.78 - Last mean reward per episode: -166.95
# Num timesteps: 408000
# Best mean reward: 215.78 - Last mean reward per episode: -168.04
# Num timesteps: 409000
# Best mean reward: 215.78 - Last mean reward per episode: -167.54
# Num timesteps: 410000
# Best mean reward: 215.78 - Last mean reward per episode: -167.54
# Num timesteps: 411000
# Best mean reward: 215.78 - Last mean reward per episode: -170.18
# Num timesteps: 412000
# Best mean reward: 215.78 - Last mean reward per episode: -167.71
# Num timesteps: 413000
# Best mean reward: 215.78 - Last mean reward per episode: -167.71
# Num timesteps: 414000
# Best mean reward: 215.78 - Last mean reward per episode: -167.62
# Num timesteps: 415000
# Best mean reward: 215.78 - Last mean reward per episode: -164.01
# Num timesteps: 416000
# Best mean reward: 215.78 - Last mean reward per episode: -164.01
# Num timesteps: 417000
# Best mean reward: 215.78 - Last mean reward per episode: -165.21
# Num timesteps: 418000
# Best mean reward: 215.78 - Last mean reward per episode: -170.02
# Num timesteps: 419000
# Best mean reward: 215.78 - Last mean reward per episode: -170.02
# Num timesteps: 420000
# Best mean reward: 215.78 - Last mean reward per episode: -172.03
# Num timesteps: 421000
# Best mean reward: 215.78 - Last mean reward per episode: -178.41
# Num timesteps: 422000
# Best mean reward: 215.78 - Last mean reward per episode: -178.41
# Num timesteps: 423000
# Best mean reward: 215.78 - Last mean reward per episode: -178.67
# Num timesteps: 424000
# Best mean reward: 215.78 - Last mean reward per episode: -176.17
# Num timesteps: 425000
# Best mean reward: 215.78 - Last mean reward per episode: -176.17
# Num timesteps: 426000
# Best mean reward: 215.78 - Last mean reward per episode: -175.42
# Num timesteps: 427000
# Best mean reward: 215.78 - Last mean reward per episode: -172.02
# Num timesteps: 428000
# Best mean reward: 215.78 - Last mean reward per episode: -172.02
# Num timesteps: 429000
# Best mean reward: 215.78 - Last mean reward per episode: -171.23
# Num timesteps: 430000
# Best mean reward: 215.78 - Last mean reward per episode: -171.43
# Num timesteps: 431000
# Best mean reward: 215.78 - Last mean reward per episode: -171.43
# Num timesteps: 432000
# Best mean reward: 215.78 - Last mean reward per episode: -177.53
# Num timesteps: 433000
# Best mean reward: 215.78 - Last mean reward per episode: -177.97
# Num timesteps: 434000
# Best mean reward: 215.78 - Last mean reward per episode: -177.97
# Num timesteps: 435000
# Best mean reward: 215.78 - Last mean reward per episode: -176.98
# Num timesteps: 436000
# Best mean reward: 215.78 - Last mean reward per episode: -177.25
# Num timesteps: 437000
# Best mean reward: 215.78 - Last mean reward per episode: -177.25
# Num timesteps: 438000
# Best mean reward: 215.78 - Last mean reward per episode: -175.56
# Num timesteps: 439000
# Best mean reward: 215.78 - Last mean reward per episode: -174.57
# Num timesteps: 440000
# Best mean reward: 215.78 - Last mean reward per episode: -174.57
# Num timesteps: 441000
# Best mean reward: 215.78 - Last mean reward per episode: -181.03
# Num timesteps: 442000
# Best mean reward: 215.78 - Last mean reward per episode: -179.55
# Num timesteps: 443000
# Best mean reward: 215.78 - Last mean reward per episode: -179.55
# Num timesteps: 444000
# Best mean reward: 215.78 - Last mean reward per episode: -183.23
# Num timesteps: 445000
# Best mean reward: 215.78 - Last mean reward per episode: -180.60
# Num timesteps: 446000
# Best mean reward: 215.78 - Last mean reward per episode: -180.60
# Num timesteps: 447000
# Best mean reward: 215.78 - Last mean reward per episode: -188.59
# Num timesteps: 448000
# Best mean reward: 215.78 - Last mean reward per episode: -192.51
# Num timesteps: 449000
# Best mean reward: 215.78 - Last mean reward per episode: -192.51
# Num timesteps: 450000
# Best mean reward: 215.78 - Last mean reward per episode: -186.33
# Num timesteps: 451000
# Best mean reward: 215.78 - Last mean reward per episode: -186.33
# Num timesteps: 452000
# Best mean reward: 215.78 - Last mean reward per episode: -186.91
# Num timesteps: 453000
# Best mean reward: 215.78 - Last mean reward per episode: -193.14
# Num timesteps: 454000
# Best mean reward: 215.78 - Last mean reward per episode: -186.69
# Num timesteps: 455000
# Best mean reward: 215.78 - Last mean reward per episode: -188.33
# Num timesteps: 456000
# Best mean reward: 215.78 - Last mean reward per episode: -188.33
# Num timesteps: 457000
# Best mean reward: 215.78 - Last mean reward per episode: -188.82
# Num timesteps: 458000
# Best mean reward: 215.78 - Last mean reward per episode: -184.84
# Num timesteps: 459000
# Best mean reward: 215.78 - Last mean reward per episode: -184.84
# Num timesteps: 460000
# Best mean reward: 215.78 - Last mean reward per episode: -185.34
# Num timesteps: 461000
# Best mean reward: 215.78 - Last mean reward per episode: -185.43
# Num timesteps: 462000
# Best mean reward: 215.78 - Last mean reward per episode: -186.54
# Num timesteps: 463000
# Best mean reward: 215.78 - Last mean reward per episode: -185.67
# Num timesteps: 464000
# Best mean reward: 215.78 - Last mean reward per episode: -182.93
# Num timesteps: 465000
# Best mean reward: 215.78 - Last mean reward per episode: -182.93
# Num timesteps: 466000
# Best mean reward: 215.78 - Last mean reward per episode: -177.41
# Num timesteps: 467000
# Best mean reward: 215.78 - Last mean reward per episode: -177.95
# Num timesteps: 468000
# Best mean reward: 215.78 - Last mean reward per episode: -177.95
# Num timesteps: 469000
# Best mean reward: 215.78 - Last mean reward per episode: -181.43
# Num timesteps: 470000
# Best mean reward: 215.78 - Last mean reward per episode: -177.11
# Num timesteps: 471000
# Best mean reward: 215.78 - Last mean reward per episode: -177.11
# Num timesteps: 472000
# Best mean reward: 215.78 - Last mean reward per episode: -178.62
# Num timesteps: 473000
# Best mean reward: 215.78 - Last mean reward per episode: -182.89
# Num timesteps: 474000
# Best mean reward: 215.78 - Last mean reward per episode: -182.89
# Num timesteps: 475000
# Best mean reward: 215.78 - Last mean reward per episode: -184.38
# Num timesteps: 476000
# Best mean reward: 215.78 - Last mean reward per episode: -184.59
# Num timesteps: 477000
# Best mean reward: 215.78 - Last mean reward per episode: -184.59
# Num timesteps: 478000
# Best mean reward: 215.78 - Last mean reward per episode: -176.69
# Num timesteps: 479000
# Best mean reward: 215.78 - Last mean reward per episode: -177.49
# Num timesteps: 480000
# Best mean reward: 215.78 - Last mean reward per episode: -177.49
# Num timesteps: 481000
# Best mean reward: 215.78 - Last mean reward per episode: -176.44
# Num timesteps: 482000
# Best mean reward: 215.78 - Last mean reward per episode: -176.76
# Num timesteps: 483000
# Best mean reward: 215.78 - Last mean reward per episode: -176.76
# Num timesteps: 484000
# Best mean reward: 215.78 - Last mean reward per episode: -177.69
# Num timesteps: 485000
# Best mean reward: 215.78 - Last mean reward per episode: -174.52
# Num timesteps: 486000
# Best mean reward: 215.78 - Last mean reward per episode: -174.52
# Num timesteps: 487000
# Best mean reward: 215.78 - Last mean reward per episode: -173.57
# Num timesteps: 488000
# Best mean reward: 215.78 - Last mean reward per episode: -173.51
# Num timesteps: 489000
# Best mean reward: 215.78 - Last mean reward per episode: -173.51
# Num timesteps: 490000
# Best mean reward: 215.78 - Last mean reward per episode: -172.02
# Num timesteps: 491000
# Best mean reward: 215.78 - Last mean reward per episode: -167.45
# Num timesteps: 492000
# Best mean reward: 215.78 - Last mean reward per episode: -167.45
# Num timesteps: 493000
# Best mean reward: 215.78 - Last mean reward per episode: -168.20
# Num timesteps: 494000
# Best mean reward: 215.78 - Last mean reward per episode: -170.87
# Num timesteps: 495000
# Best mean reward: 215.78 - Last mean reward per episode: -170.87
# Num timesteps: 496000
# Best mean reward: 215.78 - Last mean reward per episode: -172.36
# Num timesteps: 497000
# Best mean reward: 215.78 - Last mean reward per episode: -171.80
# Num timesteps: 498000
# Best mean reward: 215.78 - Last mean reward per episode: -171.80
# Num timesteps: 499000
# Best mean reward: 215.78 - Last mean reward per episode: -177.31
# Num timesteps: 500000
# Best mean reward: 215.78 - Last mean reward per episode: -175.66
# Num timesteps: 501000
# Best mean reward: 215.78 - Last mean reward per episode: -175.66
# Num timesteps: 502000
# Best mean reward: 215.78 - Last mean reward per episode: -181.92
# Num timesteps: 503000
# Best mean reward: 215.78 - Last mean reward per episode: -184.89
# Num timesteps: 504000
# Best mean reward: 215.78 - Last mean reward per episode: -188.47
# Num timesteps: 505000
# Best mean reward: 215.78 - Last mean reward per episode: -187.40
# Num timesteps: 506000
# Best mean reward: 215.78 - Last mean reward per episode: -187.40
# Num timesteps: 507000
# Best mean reward: 215.78 - Last mean reward per episode: -189.21
# Num timesteps: 508000
# Best mean reward: 215.78 - Last mean reward per episode: -189.21
# Num timesteps: 509000
# Best mean reward: 215.78 - Last mean reward per episode: -186.56
# Num timesteps: 510000
# Best mean reward: 215.78 - Last mean reward per episode: -186.42
# Num timesteps: 511000
# Best mean reward: 215.78 - Last mean reward per episode: -186.42
# Num timesteps: 512000
# Best mean reward: 215.78 - Last mean reward per episode: -186.81
# Num timesteps: 513000
# Best mean reward: 215.78 - Last mean reward per episode: -185.24
# Num timesteps: 514000
# Best mean reward: 215.78 - Last mean reward per episode: -186.28
# Num timesteps: 515000
# Best mean reward: 215.78 - Last mean reward per episode: -185.05
# Num timesteps: 516000
# Best mean reward: 215.78 - Last mean reward per episode: -185.05
# Num timesteps: 517000
# Best mean reward: 215.78 - Last mean reward per episode: -189.82
# Num timesteps: 518000
# Best mean reward: 215.78 - Last mean reward per episode: -185.82
# Num timesteps: 519000
# Best mean reward: 215.78 - Last mean reward per episode: -187.32
# Num timesteps: 520000
# Best mean reward: 215.78 - Last mean reward per episode: -187.32
# Num timesteps: 521000
# Best mean reward: 215.78 - Last mean reward per episode: -186.10
# Num timesteps: 522000
# Best mean reward: 215.78 - Last mean reward per episode: -185.59
# Num timesteps: 523000
# Best mean reward: 215.78 - Last mean reward per episode: -184.44
# ...
# Best mean reward: 215.78 - Last mean reward per episode: -144.47
# Num timesteps: 818000
# Best mean reward: 215.78 - Last mean reward per episode: -145.28
# Num timesteps: 819000
# Best mean reward: 215.78 - Last mean reward per episode: -145.24
# Num timesteps: 820000
# Best mean reward: 215.78 - Last mean reward per episode: -145.24
# Num timesteps: 821000
# Best mean reward: 215.78 - Last mean reward per episode: -146.43
# Num timesteps: 822000
# Best mean reward: 215.78 - Last mean reward per episode: -146.33
# Num timesteps: 823000
# Best mean reward: 215.78 - Last mean reward per episode: -146.33
# Num timesteps: 824000
# Best mean reward: 215.78 - Last mean reward per episode: -147.62
# Num timesteps: 825000
# Best mean reward: 215.78 - Last mean reward per episode: -147.65
# Num timesteps: 826000
# Best mean reward: 215.78 - Last mean reward per episode: -147.65
# Num timesteps: 827000
# Best mean reward: 215.78 - Last mean reward per episode: -147.01
# Num timesteps: 828000
# Best mean reward: 215.78 - Last mean reward per episode: -147.57
# Num timesteps: 829000
# Best mean reward: 215.78 - Last mean reward per episode: -147.57
# Num timesteps: 830000
# Best mean reward: 215.78 - Last mean reward per episode: -150.63
# Num timesteps: 831000
# Best mean reward: 215.78 - Last mean reward per episode: -147.90
# Num timesteps: 832000
# Best mean reward: 215.78 - Last mean reward per episode: -147.90
# Num timesteps: 833000
# Best mean reward: 215.78 - Last mean reward per episode: -145.73
# Num timesteps: 834000
# Best mean reward: 215.78 - Last mean reward per episode: -144.48
# Num timesteps: 835000
# Best mean reward: 215.78 - Last mean reward per episode: -144.48
# Num timesteps: 836000
# Best mean reward: 215.78 - Last mean reward per episode: -144.57
# Num timesteps: 837000
# Best mean reward: 215.78 - Last mean reward per episode: -147.13
# Num timesteps: 838000
# Best mean reward: 215.78 - Last mean reward per episode: -147.13
# Num timesteps: 839000
# Best mean reward: 215.78 - Last mean reward per episode: -145.05
# Num timesteps: 840000
# Best mean reward: 215.78 - Last mean reward per episode: -144.73
# Num timesteps: 841000
# Best mean reward: 215.78 - Last mean reward per episode: -144.73
# Num timesteps: 842000
# Best mean reward: 215.78 - Last mean reward per episode: -143.83
# Num timesteps: 843000
# Best mean reward: 215.78 - Last mean reward per episode: -150.34
# Num timesteps: 844000
# Best mean reward: 215.78 - Last mean reward per episode: -150.34
# Num timesteps: 845000
# Best mean reward: 215.78 - Last mean reward per episode: -152.29
# Num timesteps: 846000
# Best mean reward: 215.78 - Last mean reward per episode: -151.43
# Num timesteps: 847000
# Best mean reward: 215.78 - Last mean reward per episode: -151.43
# Num timesteps: 848000
# Best mean reward: 215.78 - Last mean reward per episode: -149.77
# Num timesteps: 849000
# Best mean reward: 215.78 - Last mean reward per episode: -151.56
# Num timesteps: 850000
# Best mean reward: 215.78 - Last mean reward per episode: -151.56
# Num timesteps: 851000
# Best mean reward: 215.78 - Last mean reward per episode: -153.61
# Num timesteps: 852000
# Best mean reward: 215.78 - Last mean reward per episode: -154.34
# Num timesteps: 853000
# Best mean reward: 215.78 - Last mean reward per episode: -154.34
# Num timesteps: 854000
# Best mean reward: 215.78 - Last mean reward per episode: -154.73
# Num timesteps: 855000
# Best mean reward: 215.78 - Last mean reward per episode: -154.27
# Num timesteps: 856000
# Best mean reward: 215.78 - Last mean reward per episode: -154.27
# Num timesteps: 857000
# Best mean reward: 215.78 - Last mean reward per episode: -152.34
# Num timesteps: 858000
# Best mean reward: 215.78 - Last mean reward per episode: -152.72
# Num timesteps: 859000
# Best mean reward: 215.78 - Last mean reward per episode: -152.72
# Num timesteps: 860000
# Best mean reward: 215.78 - Last mean reward per episode: -154.33
# Num timesteps: 861000
# Best mean reward: 215.78 - Last mean reward per episode: -153.02
# Num timesteps: 862000
# Best mean reward: 215.78 - Last mean reward per episode: -153.02
# Num timesteps: 863000
# Best mean reward: 215.78 - Last mean reward per episode: -155.23
# Num timesteps: 864000
# Best mean reward: 215.78 - Last mean reward per episode: -154.12
# Num timesteps: 865000
# Best mean reward: 215.78 - Last mean reward per episode: -154.12
# Num timesteps: 866000
# Best mean reward: 215.78 - Last mean reward per episode: -152.36
# Num timesteps: 867000
# Best mean reward: 215.78 - Last mean reward per episode: -149.88
# Num timesteps: 868000
# Best mean reward: 215.78 - Last mean reward per episode: -149.88
# Num timesteps: 869000
# Best mean reward: 215.78 - Last mean reward per episode: -149.42
# Num timesteps: 870000
# Best mean reward: 215.78 - Last mean reward per episode: -150.14
# Num timesteps: 871000
# Best mean reward: 215.78 - Last mean reward per episode: -150.14
# Num timesteps: 872000
# Best mean reward: 215.78 - Last mean reward per episode: -151.43
# Num timesteps: 873000
# Best mean reward: 215.78 - Last mean reward per episode: -149.81
# Num timesteps: 874000
# Best mean reward: 215.78 - Last mean reward per episode: -149.81
# Num timesteps: 875000
# Best mean reward: 215.78 - Last mean reward per episode: -152.01
# Num timesteps: 876000
# Best mean reward: 215.78 - Last mean reward per episode: -155.65
# Num timesteps: 877000
# Best mean reward: 215.78 - Last mean reward per episode: -155.65
# Num timesteps: 878000
# Best mean reward: 215.78 - Last mean reward per episode: -156.78
# Num timesteps: 879000
# Best mean reward: 215.78 - Last mean reward per episode: -155.85
# Num timesteps: 880000
# Best mean reward: 215.78 - Last mean reward per episode: -155.85
# Num timesteps: 881000
# Best mean reward: 215.78 - Last mean reward per episode: -153.97
# Num timesteps: 882000
# Best mean reward: 215.78 - Last mean reward per episode: -153.87
# Num timesteps: 883000
# Best mean reward: 215.78 - Last mean reward per episode: -153.87
# Num timesteps: 884000
# Best mean reward: 215.78 - Last mean reward per episode: -151.03
# Num timesteps: 885000
# Best mean reward: 215.78 - Last mean reward per episode: -151.57
# Num timesteps: 886000
# Best mean reward: 215.78 - Last mean reward per episode: -151.57
# Num timesteps: 887000
# Best mean reward: 215.78 - Last mean reward per episode: -149.82
# Num timesteps: 888000
# Best mean reward: 215.78 - Last mean reward per episode: -150.83
# Num timesteps: 889000
# Best mean reward: 215.78 - Last mean reward per episode: -150.83
# Num timesteps: 890000
# Best mean reward: 215.78 - Last mean reward per episode: -151.22
# Num timesteps: 891000
# Best mean reward: 215.78 - Last mean reward per episode: -151.49
# Num timesteps: 892000
# Best mean reward: 215.78 - Last mean reward per episode: -151.49
# Num timesteps: 893000
# Best mean reward: 215.78 - Last mean reward per episode: -153.30
# Num timesteps: 894000
# Best mean reward: 215.78 - Last mean reward per episode: -152.16
# Num timesteps: 895000
# Best mean reward: 215.78 - Last mean reward per episode: -152.16
# Num timesteps: 896000
# Best mean reward: 215.78 - Last mean reward per episode: -150.73
# Num timesteps: 897000
# Best mean reward: 215.78 - Last mean reward per episode: -147.40
# Num timesteps: 898000
# Best mean reward: 215.78 - Last mean reward per episode: -147.40
# Num timesteps: 899000
# Best mean reward: 215.78 - Last mean reward per episode: -146.88
# Num timesteps: 900000
# Best mean reward: 215.78 - Last mean reward per episode: -146.74
# Num timesteps: 901000
# Best mean reward: 215.78 - Last mean reward per episode: -146.74
# Num timesteps: 902000
# Best mean reward: 215.78 - Last mean reward per episode: -145.10
# Num timesteps: 903000
# Best mean reward: 215.78 - Last mean reward per episode: -144.27
# Num timesteps: 904000
# Best mean reward: 215.78 - Last mean reward per episode: -144.27
# Num timesteps: 905000
# Best mean reward: 215.78 - Last mean reward per episode: -141.39
# Num timesteps: 906000
# Best mean reward: 215.78 - Last mean reward per episode: -141.33
# Num timesteps: 907000
# Best mean reward: 215.78 - Last mean reward per episode: -141.33
# Num timesteps: 908000
# Best mean reward: 215.78 - Last mean reward per episode: -145.08
# Num timesteps: 909000
# Best mean reward: 215.78 - Last mean reward per episode: -144.51
# Num timesteps: 910000
# Best mean reward: 215.78 - Last mean reward per episode: -144.51
# Num timesteps: 911000
# Best mean reward: 215.78 - Last mean reward per episode: -145.57
# Num timesteps: 912000
# Best mean reward: 215.78 - Last mean reward per episode: -147.46
# Num timesteps: 913000
# Best mean reward: 215.78 - Last mean reward per episode: -147.46
# Num timesteps: 914000
# Best mean reward: 215.78 - Last mean reward per episode: -146.22
# Num timesteps: 915000
# Best mean reward: 215.78 - Last mean reward per episode: -148.90
# Num timesteps: 916000
# Best mean reward: 215.78 - Last mean reward per episode: -148.90
# Num timesteps: 917000
# Best mean reward: 215.78 - Last mean reward per episode: -151.33
# Num timesteps: 918000
# Best mean reward: 215.78 - Last mean reward per episode: -153.28
# Num timesteps: 919000
# Best mean reward: 215.78 - Last mean reward per episode: -153.28
# Num timesteps: 920000
# Best mean reward: 215.78 - Last mean reward per episode: -146.84
# Num timesteps: 921000
# Best mean reward: 215.78 - Last mean reward per episode: -148.52
# Num timesteps: 922000
# Best mean reward: 215.78 - Last mean reward per episode: -150.10
# Num timesteps: 923000
# Best mean reward: 215.78 - Last mean reward per episode: -150.10
# Num timesteps: 924000
# Best mean reward: 215.78 - Last mean reward per episode: -152.04
# Num timesteps: 925000
# Best mean reward: 215.78 - Last mean reward per episode: -155.17
# Num timesteps: 926000
# Best mean reward: 215.78 - Last mean reward per episode: -155.17
# Num timesteps: 927000
# Best mean reward: 215.78 - Last mean reward per episode: -156.90
# Num timesteps: 928000
# Best mean reward: 215.78 - Last mean reward per episode: -157.26
# Num timesteps: 929000
# Best mean reward: 215.78 - Last mean reward per episode: -157.26
# Num timesteps: 930000
# Best mean reward: 215.78 - Last mean reward per episode: -160.03
# Num timesteps: 931000
# Best mean reward: 215.78 - Last mean reward per episode: -159.86
# Num timesteps: 932000
# Best mean reward: 215.78 - Last mean reward per episode: -159.86
# Num timesteps: 933000
# Best mean reward: 215.78 - Last mean reward per episode: -157.09
# Num timesteps: 934000
# Best mean reward: 215.78 - Last mean reward per episode: -157.08
# Num timesteps: 935000
# Best mean reward: 215.78 - Last mean reward per episode: -155.42
# Num timesteps: 936000
# Best mean reward: 215.78 - Last mean reward per episode: -155.42
# Num timesteps: 937000
# Best mean reward: 215.78 - Last mean reward per episode: -155.35
# Num timesteps: 938000
# Best mean reward: 215.78 - Last mean reward per episode: -154.47
# Num timesteps: 939000
# Best mean reward: 215.78 - Last mean reward per episode: -154.47
# Num timesteps: 940000
# Best mean reward: 215.78 - Last mean reward per episode: -154.80
# Num timesteps: 941000
# Best mean reward: 215.78 - Last mean reward per episode: -153.23
# Num timesteps: 942000
# Best mean reward: 215.78 - Last mean reward per episode: -153.23
# Num timesteps: 943000
# Best mean reward: 215.78 - Last mean reward per episode: -155.55
# Num timesteps: 944000
# Best mean reward: 215.78 - Last mean reward per episode: -153.75
# Num timesteps: 945000
# Best mean reward: 215.78 - Last mean reward per episode: -153.75
# Num timesteps: 946000
# Best mean reward: 215.78 - Last mean reward per episode: -151.47
# Num timesteps: 947000
# Best mean reward: 215.78 - Last mean reward per episode: -149.85
# Num timesteps: 948000
# Best mean reward: 215.78 - Last mean reward per episode: -149.85
# Num timesteps: 949000
# Best mean reward: 215.78 - Last mean reward per episode: -148.72
# Num timesteps: 950000
# Best mean reward: 215.78 - Last mean reward per episode: -152.80
# Num timesteps: 951000
# Best mean reward: 215.78 - Last mean reward per episode: -152.80
# Num timesteps: 952000
# Best mean reward: 215.78 - Last mean reward per episode: -153.56
# Num timesteps: 953000
# Best mean reward: 215.78 - Last mean reward per episode: -156.11
# Num timesteps: 954000
# Best mean reward: 215.78 - Last mean reward per episode: -156.11
# Num timesteps: 955000
# Best mean reward: 215.78 - Last mean reward per episode: -157.09
# Num timesteps: 956000
# Best mean reward: 215.78 - Last mean reward per episode: -157.09
# Num timesteps: 957000
# Best mean reward: 215.78 - Last mean reward per episode: -157.06
# Num timesteps: 958000
# Best mean reward: 215.78 - Last mean reward per episode: -154.03
# Num timesteps: 959000
# Best mean reward: 215.78 - Last mean reward per episode: -154.03
# Num timesteps: 960000
# Best mean reward: 215.78 - Last mean reward per episode: -154.81
# Num timesteps: 961000
# Best mean reward: 215.78 - Last mean reward per episode: -153.95
# Num timesteps: 962000
# Best mean reward: 215.78 - Last mean reward per episode: -153.95
# Num timesteps: 963000
# Best mean reward: 215.78 - Last mean reward per episode: -152.39
# Num timesteps: 964000
# Best mean reward: 215.78 - Last mean reward per episode: -150.83
# Num timesteps: 965000
# Best mean reward: 215.78 - Last mean reward per episode: -150.83
# Num timesteps: 966000
# Best mean reward: 215.78 - Last mean reward per episode: -150.82
# Num timesteps: 967000
# Best mean reward: 215.78 - Last mean reward per episode: -149.19
# Num timesteps: 968000
# Best mean reward: 215.78 - Last mean reward per episode: -149.19
# Num timesteps: 969000
# Best mean reward: 215.78 - Last mean reward per episode: -150.64
# Num timesteps: 970000
# Best mean reward: 215.78 - Last mean reward per episode: -148.03
# Num timesteps: 971000
# Best mean reward: 215.78 - Last mean reward per episode: -148.03
# Num timesteps: 972000
# Best mean reward: 215.78 - Last mean reward per episode: -147.64
# Num timesteps: 973000
# Best mean reward: 215.78 - Last mean reward per episode: -147.62
# Num timesteps: 974000
# Best mean reward: 215.78 - Last mean reward per episode: -147.62
# Num timesteps: 975000
# Best mean reward: 215.78 - Last mean reward per episode: -146.43
# Num timesteps: 976000
# Best mean reward: 215.78 - Last mean reward per episode: -145.84
# Num timesteps: 977000
# Best mean reward: 215.78 - Last mean reward per episode: -151.19
# Num timesteps: 978000
# Best mean reward: 215.78 - Last mean reward per episode: -151.19
# Num timesteps: 979000
# Best mean reward: 215.78 - Last mean reward per episode: -153.46
# Num timesteps: 980000
# Best mean reward: 215.78 - Last mean reward per episode: -152.19
# Num timesteps: 981000
# Best mean reward: 215.78 - Last mean reward per episode: -152.19
# Num timesteps: 982000
# Best mean reward: 215.78 - Last mean reward per episode: -152.51
# Num timesteps: 983000
# Best mean reward: 215.78 - Last mean reward per episode: -147.28
# Num timesteps: 984000
# Best mean reward: 215.78 - Last mean reward per episode: -147.28
# Num timesteps: 985000
# Best mean reward: 215.78 - Last mean reward per episode: -146.26
# Num timesteps: 986000
# Best mean reward: 215.78 - Last mean reward per episode: -145.62
# Num timesteps: 987000
# Best mean reward: 215.78 - Last mean reward per episode: -145.62
# Num timesteps: 988000
# Best mean reward: 215.78 - Last mean reward per episode: -144.87
# Num timesteps: 989000
# Best mean reward: 215.78 - Last mean reward per episode: -140.04
# Num timesteps: 990000
# Best mean reward: 215.78 - Last mean reward per episode: -140.04
# Num timesteps: 991000
# Best mean reward: 215.78 - Last mean reward per episode: -138.25
# Num timesteps: 992000
# Best mean reward: 215.78 - Last mean reward per episode: -142.04
# Num timesteps: 993000
# Best mean reward: 215.78 - Last mean reward per episode: -142.04
# Num timesteps: 994000
# Best mean reward: 215.78 - Last mean reward per episode: -142.38
# Num timesteps: 995000
# Best mean reward: 215.78 - Last mean reward per episode: -141.96
# Num timesteps: 996000
# Best mean reward: 215.78 - Last mean reward per episode: -141.96
# Num timesteps: 997000
# Best mean reward: 215.78 - Last mean reward per episode: -140.19
# Num timesteps: 998000
# Best mean reward: 215.78 - Last mean reward per episode: -140.45
# Num timesteps: 999000
# Best mean reward: 215.78 - Last mean reward per episode: -140.45
# Num timesteps: 1000000
# Best mean reward: 215.78 - Last mean reward per episode: -140.68

# %% [markdown]
# # Record the video

# %%
# env.render(model,1)

# %% [markdown]
# # Check tensorboard

# %%
# !tensorboard --logdir ./tensorboard_logs_cont_mult/
# Out:
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.1.1 at http://localhost:6009/ (Press CTRL+C to quit)

# %% [markdown]
# # Load and check the model

# %%
log_dir = './saved_models_cont_mult/A2C/'
env = CustomEnv(obstacle_turn=False, Total_war=False)

# %%
model = A2C.load(path=log_dir + 'best_model_with_sde_2steps', env=env)

# %%
state = env.reset()
action = model.predict(state)
print(action[0][0])

# %%
velosities = []
state = env.reset()
action = model.predict(state)
for i in range(0, 100):
    state, reward, done, numstep = env.step(action[0])
    action = model.predict(state)
    velosities.append(action[0][0])
print(max(velosities), min(velosities))

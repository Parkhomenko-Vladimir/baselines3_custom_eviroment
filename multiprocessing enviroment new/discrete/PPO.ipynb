# %%
import os
import gym
import numpy as np

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy, plot_results
from stable_baselines3.common.callbacks import BaseCallback

import custom_tanks_disc_mult
from stable_baselines3.common.vec_env import SubprocVecEnv

from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
import torch.nn as nn
import torch.nn.functional as F
import torch
from stable_baselines3 import PPO

# %%
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ## Callback class

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model_PPO')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        pass
        # Create folder if needed
#         if self.save_path is not None:
#             os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print("Num timesteps: {}".format(self.num_timesteps))
                print("Best mean reward: {:.2f} - Last mean reward per episode: {:.2f}".format(self.best_mean_reward, mean_reward))

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print("Saving new best model to {}".format(self.save_path))
                  self.model.save(self.save_path)

        return True

# %% [markdown]
# ## Neural network class

# %%
import torch as th
import torch.nn as nn
import torch.nn.functional as F
import torch
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class CustomCNN(BaseFeaturesExtractor):
    """
    :param observation_space: (gym.Space)
    :param features_dim: (int) Number of features extracted.
        This corresponds to the number of unit for the last layer.
    """

    def __init__(self, observation_space: gym.spaces.Dict, features_dim: int = 518):
        super(CustomCNN, self).__init__(observation_space, features_dim)
        
        
        extractors = {}
        
        for key, subspace in observation_space.spaces.items():
            if key == "img":
        
                n_input_channels = observation_space[key].shape[0]
            
                extractors[key] = nn.Sequential(

                nn.Conv2d(n_input_channels, 32, 2),
                nn.MaxPool2d(2, 2),
                nn.Conv2d(32, 64, 2),
                nn.MaxPool2d(2, 2),

                # ResBlock(n_filters=64, kernel_size=2),
                # nn.MaxPool2d(4, 4),
                ResBlock(n_filters=64, kernel_size=2),
                nn.MaxPool2d(2, 2),
                ResBlock(n_filters=64, kernel_size=2),
                nn.MaxPool2d(2, 2),
                ResBlock(n_filters=64, kernel_size=2), 
                nn.MaxPool2d(2, 2),
                
                nn.Conv2d(64, 128, 2),
                nn.Flatten())
                    
            elif key == "posRobot":
                
                n_input_channels = observation_space[key].shape[0]
                
                extractors[key] = nn.Sequential(nn.Linear(n_input_channels, 9),
                                        nn.ReLU(),
                                        nn.Linear(9, 9),
                                        nn.ReLU(),
                                        nn.Linear(9, 3))
                    
            elif key == "target":
                            
                n_input_channels = observation_space[key].shape[0]
                    
                extractors[key] = nn.Sequential(nn.Linear(n_input_channels, 9),
                                        nn.ReLU(),
                                        nn.Linear(9, 9),
                                        nn.ReLU(),
                                        nn.Linear(9, 3))
                
        self.extractors = nn.ModuleDict(extractors)

    def forward(self, observations: th.Tensor) -> th.Tensor:
        '''
        Forward propagation
        :param observations: (dict) изображение; координаты и углы ориентации агентов
        :return: features tensor
        '''
        encoded_tensor_list = []

        for key, extractor in self.extractors.items():
            encoded_tensor_list.append(extractor(observations[key]))

        return th.cat(encoded_tensor_list, dim=1)

    
class ResBlock(nn.Module):
    def __init__(self, n_filters, kernel_size):
        """
        Инициализация кастомного резнетовского блока
        :param n_filters: (int) количество фильтров сверточного слоя
        :param kernel_size: (int) размер ядра свертки
        """
        super().__init__()
        self.n_filters = n_filters
        self.kernel_size = kernel_size

        self.b1 = nn.Conv2d(self.n_filters, self.n_filters, self.kernel_size, padding='same')
    
        self.b2 = nn.BatchNorm2d(self.n_filters, eps = 0.001, momentum= 0.99)
        self.b3 = nn.Conv2d(self.n_filters, self.n_filters, self.kernel_size, padding='same')
        self.b4 = nn.BatchNorm2d(self.n_filters, eps = 0.001, momentum= 0.99)
        
    def forward(self, x):
        '''
        Forward propagation
        :param x: input
        :return: output
        '''
        residual = x
        y = F.relu(self.b1(x))
        y = self.b2(y)
        y = F.relu(self.b3(y))
        y = self.b4(y)
        y += residual
        y = F.relu(y)
        return y

# %% [markdown]
# ## Make environment

# %%
def make_env(env_id, rank, seed=0, **kwargs):
    """
    Utility function for multiprocessed env.

    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environments you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    """
    def _init():
        env = gym.make(env_id, **kwargs)
        env.seed(seed + rank)
        log_dir = './saved_models/PPO/callback' + str(rank) + '/'  # For A2C agent: './saved_models/A2C/callback'
        os.makedirs(log_dir, exist_ok=True)
        env = Monitor(env, log_dir)
        return env
    set_random_seed(seed)
    
    return _init

# %%
env_id = 'CustomTanks_disc_mult-v0'
num_procs = 5
env = SubprocVecEnv([make_env(env_id=env_id,
                              rank=i,
                              vizualaze     = False,
                              obstacle_turn = False,
                              Total_war     = True,
                              head_velocity = 0.005,
                              num_obs       = 5,
                              num_enemy     = 1,
                              size_obs      = [30, 40],
                              rew_col       = -100,
                              rew_win       = 100, 
                              rew_defeat    = -100,
                              steps_limit   = 2000) for i in range(num_procs)], start_method='fork')
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.4)
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.4)Hello from the pygame community. https://www.pygame.org/contribute.html
#
# Hello from the pygame community. https://www.pygame.org/contribute.html
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# /home/parkhom/.local/lib/python3.10/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# /home/parkhom/.local/lib/python3.10/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# /home/parkhom/.local/lib/python3.10/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# /home/parkhom/.local/lib/python3.10/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# /home/parkhom/.local/lib/python3.10/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %% [markdown]
# ## Initialize the agent

# %%
policy_kwargs = dict(
    features_extractor_class=CustomCNN,
    features_extractor_kwargs=dict(features_dim=518),
    activation_fn=torch.nn.ReLU,
    net_arch = [dict(pi=[1029, 128, 32, 8], vf=[1029, 128, 32, 8])])

model = PPO(policy          = 'MultiInputPolicy',
            env             = env,
            learning_rate   = 0.0001,
            n_steps         = 125,
            batch_size      = 5,
            gamma           = 0.99,
            gae_lambda      = 0.95,
            tensorboard_log = "./tensorboard_logs/",
            policy_kwargs   = policy_kwargs,
            verbose         = 2,
            device          = 'cuda:0')

# model = A2C(policy          = 'MlpPolicy',
#             env             = env,
#             learning_rate   = 0.0001,
#             n_steps         = 24,
#             gamma           = 0.99,
#             gae_lambda      = 0.95,
#             tensorboard_log = "./tensorboard_logs/",
#             policy_kwargs   = policy_kwargs,
#             verbose         = 0,
#             device          = 'cuda')
# Out:
# Using cuda:0 device
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# ## Make callback

# %%
log_dir = './saved_models/PPO/callback0/'  # For A2C agent: './saved_models/A2C/callback'
callback = SaveOnBestTrainingRewardCallback(check_freq=5000, log_dir=log_dir)

# %% [markdown]
# ## Learn the model

# %%
model.learn(total_timesteps=1e6,callback=callback)
# Out:
# Logging to ./tensorboard_logs/PPO_1
# /home/parkhom/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:453: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:882.)
#   return F.conv2d(input, weight, bias, self.stride,
# ----------------------------
# | time/              |     |
# |    fps             | 114 |
# |    iterations      | 1   |
# |    time_elapsed    | 5   |
# |    total_timesteps | 625 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 2           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 1250        |
# | train/                  |             |
# |    approx_kl            | 0.016227538 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | -0.00438    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 29.1        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0242     |
# |    value_loss           | 219         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | 27.2        |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 3           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 1875        |
# | train/                  |             |
# |    approx_kl            | 0.016496025 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.0196      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 191         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 168         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 372        |
# |    ep_rew_mean          | -204       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 4          |
# |    time_elapsed         | 117        |
# |    total_timesteps      | 2500       |
# | train/                  |            |
# |    approx_kl            | 0.02730339 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.99      |
# |    explained_variance   | -0.116     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 20.6       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0252    |
# |    value_loss           | 168        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 395         |
# |    ep_rew_mean          | -324        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 5           |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 3125        |
# | train/                  |             |
# |    approx_kl            | 0.015596256 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.0557      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 33.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 364         |
# |    ep_rew_mean          | -462        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 6           |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 3750        |
# | train/                  |             |
# |    approx_kl            | 0.024226414 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | -0.271      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.49        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 158         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 333         |
# |    ep_rew_mean          | -441        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 7           |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 4375        |
# | train/                  |             |
# |    approx_kl            | 0.014224194 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 20.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 328         |
# |    ep_rew_mean          | -442        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 8           |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.021040278 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.126      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 127         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 312       |
# |    ep_rew_mean          | -434      |
# | time/                   |           |
# |    fps                  | 18        |
# |    iterations           | 9         |
# |    time_elapsed         | 303       |
# |    total_timesteps      | 5625      |
# | train/                  |           |
# |    approx_kl            | 0.0198691 |
# |    clip_fraction        | 0.208     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.97     |
# |    explained_variance   | -0.291    |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.65      |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -0.0109   |
# |    value_loss           | 93.2      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 295         |
# |    ep_rew_mean          | -439        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 10          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 6250        |
# | train/                  |             |
# |    approx_kl            | 0.027748711 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.55        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 114         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 310        |
# |    ep_rew_mean          | -462       |
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 11         |
# |    time_elapsed         | 378        |
# |    total_timesteps      | 6875       |
# | train/                  |            |
# |    approx_kl            | 0.01722875 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | 0.597      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 85.8       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00875   |
# |    value_loss           | 191        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 305         |
# |    ep_rew_mean          | -426        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 12          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 7500        |
# | train/                  |             |
# |    approx_kl            | 0.017366633 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 12.6        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 201         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | -416        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 13          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 8125        |
# | train/                  |             |
# |    approx_kl            | 0.024121704 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 27.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 140         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | -476        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 14          |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 8750        |
# | train/                  |             |
# |    approx_kl            | 0.018047467 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.1         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 134         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 305         |
# |    ep_rew_mean          | -468        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 15          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 9375        |
# | train/                  |             |
# |    approx_kl            | 0.024882687 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 33.2        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 158         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 295        |
# |    ep_rew_mean          | -422       |
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 16         |
# |    time_elapsed         | 563        |
# |    total_timesteps      | 10000      |
# | train/                  |            |
# |    approx_kl            | 0.02124856 |
# |    clip_fraction        | 0.289      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.93      |
# |    explained_variance   | 0.0374     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 10.9       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0228    |
# |    value_loss           | 127        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -419        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 17          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 10625       |
# | train/                  |             |
# |    approx_kl            | 0.018405607 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.0449      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.8        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | -403        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 18          |
# |    time_elapsed         | 636         |
# |    total_timesteps      | 11250       |
# | train/                  |             |
# |    approx_kl            | 0.023335915 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.063       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 42.3        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 97.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | -403        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 19          |
# |    time_elapsed         | 674         |
# |    total_timesteps      | 11875       |
# | train/                  |             |
# |    approx_kl            | 0.030353645 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | -0.0049     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.67        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 235         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | -379        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 20          |
# |    time_elapsed         | 711         |
# |    total_timesteps      | 12500       |
# | train/                  |             |
# |    approx_kl            | 0.024169361 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 45.2        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | -403        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 21          |
# |    time_elapsed         | 748         |
# |    total_timesteps      | 13125       |
# | train/                  |             |
# |    approx_kl            | 0.050891574 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 30.1        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 69.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 305         |
# |    ep_rew_mean          | -379        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 22          |
# |    time_elapsed         | 786         |
# |    total_timesteps      | 13750       |
# | train/                  |             |
# |    approx_kl            | 0.026889773 |
# |    clip_fraction        | 0.353       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 40.6        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 309         |
# |    ep_rew_mean          | -399        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 23          |
# |    time_elapsed         | 823         |
# |    total_timesteps      | 14375       |
# | train/                  |             |
# |    approx_kl            | 0.027636917 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.24        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 154         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | -418        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 24          |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.027314687 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.5        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 313         |
# |    ep_rew_mean          | -406        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 25          |
# |    time_elapsed         | 897         |
# |    total_timesteps      | 15625       |
# | train/                  |             |
# |    approx_kl            | 0.030897852 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.5        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 150         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 316        |
# |    ep_rew_mean          | -394       |
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 26         |
# |    time_elapsed         | 935        |
# |    total_timesteps      | 16250      |
# | train/                  |            |
# |    approx_kl            | 0.02613196 |
# |    clip_fraction        | 0.345      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.85      |
# |    explained_variance   | 0.651      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 37         |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0286    |
# |    value_loss           | 163        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 311       |
# |    ep_rew_mean          | -391      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 27        |
# |    time_elapsed         | 973       |
# |    total_timesteps      | 16875     |
# | train/                  |           |
# |    approx_kl            | 0.0248003 |
# |    clip_fraction        | 0.276     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.86     |
# |    explained_variance   | -0.0833   |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.92      |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -0.0105   |
# |    value_loss           | 156       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | -391        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 28          |
# |    time_elapsed         | 1009        |
# |    total_timesteps      | 17500       |
# | train/                  |             |
# |    approx_kl            | 0.023292692 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.8        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | -391        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 29          |
# |    time_elapsed         | 1046        |
# |    total_timesteps      | 18125       |
# | train/                  |             |
# |    approx_kl            | 0.024179723 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 59.9        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 320         |
# |    ep_rew_mean          | -403        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 30          |
# |    time_elapsed         | 1084        |
# |    total_timesteps      | 18750       |
# | train/                  |             |
# |    approx_kl            | 0.031989038 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.6        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | -409        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 31          |
# |    time_elapsed         | 1120        |
# |    total_timesteps      | 19375       |
# | train/                  |             |
# |    approx_kl            | 0.026357325 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.6        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 144         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 323        |
# |    ep_rew_mean          | -415       |
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 32         |
# |    time_elapsed         | 1158       |
# |    total_timesteps      | 20000      |
# | train/                  |            |
# |    approx_kl            | 0.02346561 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.91      |
# |    explained_variance   | 0.648      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 22.8       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0169    |
# |    value_loss           | 108        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 319         |
# |    ep_rew_mean          | -411        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 33          |
# |    time_elapsed         | 1195        |
# |    total_timesteps      | 20625       |
# | train/                  |             |
# |    approx_kl            | 0.031961765 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 35.8        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | -394        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 34          |
# |    time_elapsed         | 1232        |
# |    total_timesteps      | 21250       |
# | train/                  |             |
# |    approx_kl            | 0.035111155 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | -0.321      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 19.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 295         |
# |    ep_rew_mean          | -392        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 35          |
# |    time_elapsed         | 1269        |
# |    total_timesteps      | 21875       |
# | train/                  |             |
# |    approx_kl            | 0.023958355 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.089       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 35.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 174         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 291         |
# |    ep_rew_mean          | -386        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 36          |
# |    time_elapsed         | 1306        |
# |    total_timesteps      | 22500       |
# | train/                  |             |
# |    approx_kl            | 0.059581324 |
# |    clip_fraction        | 0.431       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15          |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 37          |
# |    time_elapsed         | 1344        |
# |    total_timesteps      | 23125       |
# | train/                  |             |
# |    approx_kl            | 0.040341113 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.13        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 85.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 283        |
# |    ep_rew_mean          | -360       |
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 38         |
# |    time_elapsed         | 1381       |
# |    total_timesteps      | 23750      |
# | train/                  |            |
# |    approx_kl            | 0.03557501 |
# |    clip_fraction        | 0.293      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.77      |
# |    explained_variance   | 0.0217     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 18.8       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 127        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 281         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 39          |
# |    time_elapsed         | 1417        |
# |    total_timesteps      | 24375       |
# | train/                  |             |
# |    approx_kl            | 0.034078375 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.5        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 158         |
# -----------------------------------------
# Num timesteps: 25000
# Best mean reward: -inf - Last mean reward per episode: -347.82
# Saving new best model to ./saved_models/PPO/callback0/best_model_PPO
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 281         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 40          |
# |    time_elapsed         | 1455        |
# |    total_timesteps      | 25000       |
# | train/                  |             |
# |    approx_kl            | 0.049948115 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.5        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 80.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 283         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 41          |
# |    time_elapsed         | 1491        |
# |    total_timesteps      | 25625       |
# | train/                  |             |
# |    approx_kl            | 0.032858163 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.47        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 74.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 42          |
# |    time_elapsed         | 1528        |
# |    total_timesteps      | 26250       |
# | train/                  |             |
# |    approx_kl            | 0.028980529 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.0544      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 16.3        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0286     |
# |    value_loss           | 138         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 287         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 43          |
# |    time_elapsed         | 1565        |
# |    total_timesteps      | 26875       |
# | train/                  |             |
# |    approx_kl            | 0.030228151 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 16.4        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0095     |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | -338        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 44          |
# |    time_elapsed         | 1602        |
# |    total_timesteps      | 27500       |
# | train/                  |             |
# |    approx_kl            | 0.035944525 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.2        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 283         |
# |    ep_rew_mean          | -331        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 45          |
# |    time_elapsed         | 1639        |
# |    total_timesteps      | 28125       |
# | train/                  |             |
# |    approx_kl            | 0.032303885 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | -0.354      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.4        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 148         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 282        |
# |    ep_rew_mean          | -324       |
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 46         |
# |    time_elapsed         | 1676       |
# |    total_timesteps      | 28750      |
# | train/                  |            |
# |    approx_kl            | 0.04259866 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.73      |
# |    explained_variance   | -0.0281    |
# |    learning_rate        | 0.0001     |
# |    loss                 | 14         |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.017     |
# |    value_loss           | 81.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 276        |
# |    ep_rew_mean          | -321       |
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 47         |
# |    time_elapsed         | 1713       |
# |    total_timesteps      | 29375      |
# | train/                  |            |
# |    approx_kl            | 0.03062233 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.79      |
# |    explained_variance   | 0.174      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 7.23       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0193    |
# |    value_loss           | 73.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | -307        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 48          |
# |    time_elapsed         | 1750        |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.036654897 |
# |    clip_fraction        | 0.372       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.6        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 93.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 263        |
# |    ep_rew_mean          | -287       |
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 49         |
# |    time_elapsed         | 1787       |
# |    total_timesteps      | 30625      |
# | train/                  |            |
# |    approx_kl            | 0.03513509 |
# |    clip_fraction        | 0.362      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | 0.0915     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 10.5       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 93.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 263         |
# |    ep_rew_mean          | -287        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 50          |
# |    time_elapsed         | 1825        |
# |    total_timesteps      | 31250       |
# | train/                  |             |
# |    approx_kl            | 0.030845547 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.0229      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 20.8        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 95.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 267         |
# |    ep_rew_mean          | -290        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 51          |
# |    time_elapsed         | 1862        |
# |    total_timesteps      | 31875       |
# | train/                  |             |
# |    approx_kl            | 0.045226436 |
# |    clip_fraction        | 0.426       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 29.7        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 80.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | -294        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 52          |
# |    time_elapsed         | 1900        |
# |    total_timesteps      | 32500       |
# | train/                  |             |
# |    approx_kl            | 0.032156084 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.7        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 124         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | -289        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 53          |
# |    time_elapsed         | 1938        |
# |    total_timesteps      | 33125       |
# | train/                  |             |
# |    approx_kl            | 0.028271275 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.02        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 183         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | -292        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 54          |
# |    time_elapsed         | 1976        |
# |    total_timesteps      | 33750       |
# | train/                  |             |
# |    approx_kl            | 0.029602086 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 16.6        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | -313        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 55          |
# |    time_elapsed         | 2014        |
# |    total_timesteps      | 34375       |
# | train/                  |             |
# |    approx_kl            | 0.026289929 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.14        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# ...
# |    value_loss           | 124         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 147        |
# |    ep_rew_mean          | 111        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 193        |
# |    time_elapsed         | 7177       |
# |    total_timesteps      | 120625     |
# | train/                  |            |
# |    approx_kl            | 0.03715397 |
# |    clip_fraction        | 0.366      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.562      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 7.8        |
# |    n_updates            | 1920       |
# |    policy_gradient_loss | -0.0187    |
# |    value_loss           | 151        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 194         |
# |    time_elapsed         | 7214        |
# |    total_timesteps      | 121250      |
# | train/                  |             |
# |    approx_kl            | 0.035292953 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 37.3        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00865    |
# |    value_loss           | 216         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 195         |
# |    time_elapsed         | 7251        |
# |    total_timesteps      | 121875      |
# | train/                  |             |
# |    approx_kl            | 0.040006783 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 65.7        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 155         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 196         |
# |    time_elapsed         | 7288        |
# |    total_timesteps      | 122500      |
# | train/                  |             |
# |    approx_kl            | 0.079141766 |
# |    clip_fraction        | 0.469       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.8        |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 95          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 121         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 197         |
# |    time_elapsed         | 7325        |
# |    total_timesteps      | 123125      |
# | train/                  |             |
# |    approx_kl            | 0.049451742 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.2        |
# |    n_updates            | 1960        |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 119         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 198         |
# |    time_elapsed         | 7363        |
# |    total_timesteps      | 123750      |
# | train/                  |             |
# |    approx_kl            | 0.057919145 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 46.6        |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 199         |
# |    time_elapsed         | 7400        |
# |    total_timesteps      | 124375      |
# | train/                  |             |
# |    approx_kl            | 0.045924243 |
# |    clip_fraction        | 0.421       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.425       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 39.7        |
# |    n_updates            | 1980        |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 125         |
# -----------------------------------------
# Num timesteps: 125000
# Best mean reward: -209.02 - Last mean reward per episode: -63.83
# Saving new best model to ./saved_models/PPO/callback0/best_model_PPO
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 158        |
# |    ep_rew_mean          | 124        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 200        |
# |    time_elapsed         | 7436       |
# |    total_timesteps      | 125000     |
# | train/                  |            |
# |    approx_kl            | 0.04483947 |
# |    clip_fraction        | 0.422      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.623      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 33.5       |
# |    n_updates            | 1990       |
# |    policy_gradient_loss | -0.00374   |
# |    value_loss           | 136        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 158        |
# |    ep_rew_mean          | 125        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 201        |
# |    time_elapsed         | 7473       |
# |    total_timesteps      | 125625     |
# | train/                  |            |
# |    approx_kl            | 0.07238177 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.51      |
# |    explained_variance   | 0.269      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.21       |
# |    n_updates            | 2000       |
# |    policy_gradient_loss | -0.0183    |
# |    value_loss           | 112        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 124         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 202         |
# |    time_elapsed         | 7510        |
# |    total_timesteps      | 126250      |
# | train/                  |             |
# |    approx_kl            | 0.041347172 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.33        |
# |    n_updates            | 2010        |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 203         |
# |    time_elapsed         | 7547        |
# |    total_timesteps      | 126875      |
# | train/                  |             |
# |    approx_kl            | 0.033470348 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 29.3        |
# |    n_updates            | 2020        |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 246         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 157        |
# |    ep_rew_mean          | 131        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 204        |
# |    time_elapsed         | 7585       |
# |    total_timesteps      | 127500     |
# | train/                  |            |
# |    approx_kl            | 0.04045518 |
# |    clip_fraction        | 0.364      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.47      |
# |    explained_variance   | 0.575      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 13.3       |
# |    n_updates            | 2030       |
# |    policy_gradient_loss | -0.0185    |
# |    value_loss           | 141        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 155        |
# |    ep_rew_mean          | 137        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 205        |
# |    time_elapsed         | 7622       |
# |    total_timesteps      | 128125     |
# | train/                  |            |
# |    approx_kl            | 0.04117231 |
# |    clip_fraction        | 0.354      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.5       |
# |    explained_variance   | 0.699      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 44.1       |
# |    n_updates            | 2040       |
# |    policy_gradient_loss | -0.0221    |
# |    value_loss           | 201        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 206         |
# |    time_elapsed         | 7659        |
# |    total_timesteps      | 128750      |
# | train/                  |             |
# |    approx_kl            | 0.068277664 |
# |    clip_fraction        | 0.497       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.76        |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | -0.0353     |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 207         |
# |    time_elapsed         | 7697        |
# |    total_timesteps      | 129375      |
# | train/                  |             |
# |    approx_kl            | 0.041154284 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.2        |
# |    n_updates            | 2060        |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 117         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 156        |
# |    ep_rew_mean          | 149        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 208        |
# |    time_elapsed         | 7733       |
# |    total_timesteps      | 130000     |
# | train/                  |            |
# |    approx_kl            | 0.04604215 |
# |    clip_fraction        | 0.441      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | -0.0266    |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.92       |
# |    n_updates            | 2070       |
# |    policy_gradient_loss | -0.021     |
# |    value_loss           | 101        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 209         |
# |    time_elapsed         | 7769        |
# |    total_timesteps      | 130625      |
# | train/                  |             |
# |    approx_kl            | 0.050906356 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.4        |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 92          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 121         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 210         |
# |    time_elapsed         | 7806        |
# |    total_timesteps      | 131250      |
# | train/                  |             |
# |    approx_kl            | 0.062031463 |
# |    clip_fraction        | 0.437       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | -0.35       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.41        |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 99.7        |
# -----------------------------------------

# %% [markdown]
# ## Make environment and load the best model to test trained model and get statistics

# %%
path = './saved_models/PPO/callback0/best_model_PPO/'  # For A2C agent: './saved_models/A2C/callback0/best_model_A2C/'
model = PPO.load(path, env=env_test)  # For A2C agent: A2C.load(path, env=env_test)

# %%
env.get_statistic(model, 1000)

# %% [markdown]
# ## Check tensorboard

# %%
# !tensorboard --logdir ./tensorboard_logs/

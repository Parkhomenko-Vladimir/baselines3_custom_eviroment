# %%
import os
import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy, plot_results
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback

from gym_env_3steps_in_1img import CustomEnv  # gym_environment3layers for 3-layer input image
from network import CustomCNN

from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
import torch.nn as nn
import torch.nn.functional as F
import torch
from stable_baselines3 import PPO


torch.backends.cudnn.benchmark = True
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Collab callback class

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model_PPO')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        pass
        # Create folder if needed
#         if self.save_path is not None:
#             os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print("Num timesteps: {}".format(self.num_timesteps))
                print("Best mean reward: {:.2f} - Last mean reward per episode: {:.2f}".format(self.best_mean_reward, mean_reward))

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print("Saving new best model to {}".format(self.save_path))
                  self.model.save(self.save_path)

        return True

# %% [markdown]
# # Init logs, model, environment

# %%
log_dir = './saved_models_cont_mult/PPO/'
os.makedirs(log_dir, exist_ok=True)
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)


env = CustomEnv(obstacle_turn = False, 
                vizualaze     = False, 
                Total_war     = True,
                head_velocity = 0.005,
                num_obs       = 5, 
                num_enemy     = 1, 
                size_obs = [30, 40],
                steps_limit    = 2000)

env = Monitor(env, log_dir)

policy_kwargs = dict(
    features_extractor_class=CustomCNN,
    features_extractor_kwargs=dict(features_dim=518),
    activation_fn=torch.nn.ReLU,
    net_arch = [dict(pi=[1029, 128, 32, 8], vf=[1029, 128, 32, 8])])

model = PPO(policy          = 'MlpPolicy',
            env             = env,
            learning_rate   = 0.0001,
            n_steps         = 2048,
            batch_size      = 24,
            gamma           = 0.99,
            gae_lambda      = 0.95,
            tensorboard_log = "./tensorboard_logs_cont_mult/",
            policy_kwargs   = policy_kwargs,
            verbose         = 0,
            device          = 'cuda')
# Out:
# /home/tatiana/environments/tatenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float16
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/tatiana/environments/tatenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/tatiana/environments/tatenv/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py:137: UserWarning: You have specified a mini-batch size of 24, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2048`, after every 85 untruncated mini-batches, there will be a truncated mini-batch of size 8
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2048 and n_envs=1)
#   warnings.warn(

# %% [markdown]
# # Run learning

# %%
model.learn(total_timesteps=1e6,callback=callback)
# Out:
# /home/tatiana/environments/tatenv/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /home/tatiana/environments/tatenv/lib/python3.8/site-packages/torch/nn/modules/conv.py:439: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  /pytorch/aten/src/ATen/native/Convolution.cpp:660.)
#   return F.conv2d(input, weight, bias, self.stride,
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -460.33
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 2000
# Best mean reward: -460.33 - Last mean reward per episode: -480.48
# Num timesteps: 3000
# Best mean reward: -460.33 - Last mean reward per episode: -571.63
# Num timesteps: 4000
# Best mean reward: -460.33 - Last mean reward per episode: -513.32
# Num timesteps: 5000
# Best mean reward: -460.33 - Last mean reward per episode: -473.72
# Num timesteps: 6000
# Best mean reward: -460.33 - Last mean reward per episode: -518.00
# Num timesteps: 7000
# Best mean reward: -460.33 - Last mean reward per episode: -509.50
# Num timesteps: 8000
# Best mean reward: -460.33 - Last mean reward per episode: -529.14
# Num timesteps: 9000
# Best mean reward: -460.33 - Last mean reward per episode: -527.90
# Num timesteps: 10000
# Best mean reward: -460.33 - Last mean reward per episode: -541.77
# Num timesteps: 11000
# Best mean reward: -460.33 - Last mean reward per episode: -598.34
# Num timesteps: 12000
# Best mean reward: -460.33 - Last mean reward per episode: -615.11
# Num timesteps: 13000
# Best mean reward: -460.33 - Last mean reward per episode: -606.90
# Num timesteps: 14000
# Best mean reward: -460.33 - Last mean reward per episode: -629.98
# Num timesteps: 15000
# Best mean reward: -460.33 - Last mean reward per episode: -637.29
# Num timesteps: 16000
# Best mean reward: -460.33 - Last mean reward per episode: -651.95
# Num timesteps: 17000
# Best mean reward: -460.33 - Last mean reward per episode: -644.45
# Num timesteps: 18000
# Best mean reward: -460.33 - Last mean reward per episode: -647.15
# Num timesteps: 19000
# Best mean reward: -460.33 - Last mean reward per episode: -702.60
# Num timesteps: 20000
# Best mean reward: -460.33 - Last mean reward per episode: -738.21
# Num timesteps: 21000
# Best mean reward: -460.33 - Last mean reward per episode: -737.74
# Num timesteps: 22000
# Best mean reward: -460.33 - Last mean reward per episode: -746.16
# Num timesteps: 23000
# Best mean reward: -460.33 - Last mean reward per episode: -795.71
# Num timesteps: 24000
# Best mean reward: -460.33 - Last mean reward per episode: -842.02
# Num timesteps: 25000
# Best mean reward: -460.33 - Last mean reward per episode: -841.26
# Num timesteps: 26000
# Best mean reward: -460.33 - Last mean reward per episode: -840.73
# Num timesteps: 27000
# Best mean reward: -460.33 - Last mean reward per episode: -898.83
# Num timesteps: 28000
# Best mean reward: -460.33 - Last mean reward per episode: -933.03
# Num timesteps: 29000
# Best mean reward: -460.33 - Last mean reward per episode: -943.68
# Num timesteps: 30000
# Best mean reward: -460.33 - Last mean reward per episode: -943.68
# Num timesteps: 31000
# Best mean reward: -460.33 - Last mean reward per episode: -1023.13
# Num timesteps: 32000
# Best mean reward: -460.33 - Last mean reward per episode: -1023.13
# Num timesteps: 33000
# Best mean reward: -460.33 - Last mean reward per episode: -1156.74
# Num timesteps: 34000
# Best mean reward: -460.33 - Last mean reward per episode: -1156.74
# Num timesteps: 35000
# Best mean reward: -460.33 - Last mean reward per episode: -1207.75
# Num timesteps: 36000
# Best mean reward: -460.33 - Last mean reward per episode: -1222.42
# Num timesteps: 37000
# Best mean reward: -460.33 - Last mean reward per episode: -1244.22
# Num timesteps: 38000
# Best mean reward: -460.33 - Last mean reward per episode: -1241.78
# Num timesteps: 39000
# Best mean reward: -460.33 - Last mean reward per episode: -1226.19
# Num timesteps: 40000
# Best mean reward: -460.33 - Last mean reward per episode: -1271.31
# Num timesteps: 41000
# Best mean reward: -460.33 - Last mean reward per episode: -1279.03
# Num timesteps: 42000
# Best mean reward: -460.33 - Last mean reward per episode: -1330.53
# Num timesteps: 43000
# Best mean reward: -460.33 - Last mean reward per episode: -1325.59
# Num timesteps: 44000
# Best mean reward: -460.33 - Last mean reward per episode: -1303.78
# Num timesteps: 45000
# Best mean reward: -460.33 - Last mean reward per episode: -1295.86
# Num timesteps: 46000
# Best mean reward: -460.33 - Last mean reward per episode: -1298.42
# Num timesteps: 47000
# Best mean reward: -460.33 - Last mean reward per episode: -1308.19
# Num timesteps: 48000
# Best mean reward: -460.33 - Last mean reward per episode: -1274.62
# Num timesteps: 49000
# Best mean reward: -460.33 - Last mean reward per episode: -1243.51
# Num timesteps: 50000
# Best mean reward: -460.33 - Last mean reward per episode: -1243.51
# Num timesteps: 51000
# Best mean reward: -460.33 - Last mean reward per episode: -1277.17
# Num timesteps: 52000
# Best mean reward: -460.33 - Last mean reward per episode: -1281.25
# Num timesteps: 53000
# Best mean reward: -460.33 - Last mean reward per episode: -1314.67
# Num timesteps: 54000
# Best mean reward: -460.33 - Last mean reward per episode: -1314.67
# Num timesteps: 55000
# Best mean reward: -460.33 - Last mean reward per episode: -1260.48
# Num timesteps: 56000
# Best mean reward: -460.33 - Last mean reward per episode: -1259.88
# Num timesteps: 57000
# Best mean reward: -460.33 - Last mean reward per episode: -1132.39
# Num timesteps: 58000
# Best mean reward: -460.33 - Last mean reward per episode: -1132.92
# Num timesteps: 59000
# Best mean reward: -460.33 - Last mean reward per episode: -1024.77
# Num timesteps: 60000
# Best mean reward: -460.33 - Last mean reward per episode: -788.76
# Num timesteps: 61000
# Best mean reward: -460.33 - Last mean reward per episode: -667.21
# Num timesteps: 62000
# Best mean reward: -460.33 - Last mean reward per episode: -628.22
# Num timesteps: 63000
# Best mean reward: -460.33 - Last mean reward per episode: -617.08
# Num timesteps: 64000
# Best mean reward: -460.33 - Last mean reward per episode: -634.48
# Num timesteps: 65000
# Best mean reward: -460.33 - Last mean reward per episode: -483.27
# Num timesteps: 66000
# Best mean reward: -460.33 - Last mean reward per episode: -418.82
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 67000
# Best mean reward: -418.82 - Last mean reward per episode: -365.37
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 68000
# Best mean reward: -365.37 - Last mean reward per episode: -359.51
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 69000
# Best mean reward: -359.51 - Last mean reward per episode: -291.29
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 70000
# Best mean reward: -291.29 - Last mean reward per episode: -156.37
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 71000
# Best mean reward: -156.37 - Last mean reward per episode: -140.30
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 72000
# Best mean reward: -140.30 - Last mean reward per episode: -128.19
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 73000
# Best mean reward: -128.19 - Last mean reward per episode: -88.95
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 74000
# Best mean reward: -88.95 - Last mean reward per episode: -84.56
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 75000
# Best mean reward: -84.56 - Last mean reward per episode: -110.58
# Num timesteps: 76000
# Best mean reward: -84.56 - Last mean reward per episode: -113.32
# Num timesteps: 77000
# Best mean reward: -84.56 - Last mean reward per episode: -93.23
# Num timesteps: 78000
# Best mean reward: -84.56 - Last mean reward per episode: -105.61
# Num timesteps: 79000
# Best mean reward: -84.56 - Last mean reward per episode: -106.51
# Num timesteps: 80000
# Best mean reward: -84.56 - Last mean reward per episode: -79.19
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 81000
# Best mean reward: -79.19 - Last mean reward per episode: -83.46
# Num timesteps: 82000
# Best mean reward: -79.19 - Last mean reward per episode: -60.48
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 83000
# Best mean reward: -60.48 - Last mean reward per episode: -69.97
# Num timesteps: 84000
# Best mean reward: -60.48 - Last mean reward per episode: -43.14
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 85000
# Best mean reward: -43.14 - Last mean reward per episode: -46.34
# Num timesteps: 86000
# Best mean reward: -43.14 - Last mean reward per episode: -53.03
# Num timesteps: 87000
# Best mean reward: -43.14 - Last mean reward per episode: -23.55
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 88000
# Best mean reward: -23.55 - Last mean reward per episode: -32.94
# Num timesteps: 89000
# Best mean reward: -23.55 - Last mean reward per episode: -58.07
# Num timesteps: 90000
# Best mean reward: -23.55 - Last mean reward per episode: -54.64
# Num timesteps: 91000
# Best mean reward: -23.55 - Last mean reward per episode: -71.60
# Num timesteps: 92000
# Best mean reward: -23.55 - Last mean reward per episode: -55.93
# Num timesteps: 93000
# Best mean reward: -23.55 - Last mean reward per episode: -36.21
# Num timesteps: 94000
# Best mean reward: -23.55 - Last mean reward per episode: -28.56
# Num timesteps: 95000
# Best mean reward: -23.55 - Last mean reward per episode: -18.65
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 96000
# Best mean reward: -18.65 - Last mean reward per episode: -16.27
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 97000
# Best mean reward: -16.27 - Last mean reward per episode: 28.08
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 98000
# Best mean reward: 28.08 - Last mean reward per episode: 45.37
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 99000
# Best mean reward: 45.37 - Last mean reward per episode: 81.57
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 100000
# Best mean reward: 81.57 - Last mean reward per episode: 96.87
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 101000
# Best mean reward: 96.87 - Last mean reward per episode: 134.88
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 102000
# Best mean reward: 134.88 - Last mean reward per episode: 157.00
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 103000
# Best mean reward: 157.00 - Last mean reward per episode: 133.65
# Num timesteps: 104000
# Best mean reward: 157.00 - Last mean reward per episode: 131.09
# Num timesteps: 105000
# Best mean reward: 157.00 - Last mean reward per episode: 107.29
# Num timesteps: 106000
# Best mean reward: 157.00 - Last mean reward per episode: 131.52
# Num timesteps: 107000
# Best mean reward: 157.00 - Last mean reward per episode: 92.12
# Num timesteps: 108000
# Best mean reward: 157.00 - Last mean reward per episode: 65.35
# Num timesteps: 109000
# Best mean reward: 157.00 - Last mean reward per episode: 49.81
# Num timesteps: 110000
# Best mean reward: 157.00 - Last mean reward per episode: 49.98
# Num timesteps: 111000
# Best mean reward: 157.00 - Last mean reward per episode: 70.01
# Num timesteps: 112000
# Best mean reward: 157.00 - Last mean reward per episode: 62.95
# Num timesteps: 113000
# Best mean reward: 157.00 - Last mean reward per episode: 71.31
# Num timesteps: 114000
# Best mean reward: 157.00 - Last mean reward per episode: 88.34
# Num timesteps: 115000
# Best mean reward: 157.00 - Last mean reward per episode: 105.05
# Num timesteps: 116000
# Best mean reward: 157.00 - Last mean reward per episode: 88.80
# Num timesteps: 117000
# Best mean reward: 157.00 - Last mean reward per episode: 129.15
# Num timesteps: 118000
# Best mean reward: 157.00 - Last mean reward per episode: 120.36
# Num timesteps: 119000
# Best mean reward: 157.00 - Last mean reward per episode: 132.90
# Num timesteps: 120000
# Best mean reward: 157.00 - Last mean reward per episode: 119.86
# Num timesteps: 121000
# Best mean reward: 157.00 - Last mean reward per episode: 98.86
# Num timesteps: 122000
# Best mean reward: 157.00 - Last mean reward per episode: 114.66
# Num timesteps: 123000
# Best mean reward: 157.00 - Last mean reward per episode: 126.29
# Num timesteps: 124000
# Best mean reward: 157.00 - Last mean reward per episode: 116.77
# Num timesteps: 125000
# Best mean reward: 157.00 - Last mean reward per episode: 103.39
# Num timesteps: 126000
# Best mean reward: 157.00 - Last mean reward per episode: 104.14
# Num timesteps: 127000
# Best mean reward: 157.00 - Last mean reward per episode: 88.53
# Num timesteps: 128000
# Best mean reward: 157.00 - Last mean reward per episode: 83.23
# Num timesteps: 129000
# Best mean reward: 157.00 - Last mean reward per episode: 41.22
# Num timesteps: 130000
# Best mean reward: 157.00 - Last mean reward per episode: 38.27
# Num timesteps: 131000
# Best mean reward: 157.00 - Last mean reward per episode: 35.69
# Num timesteps: 132000
# Best mean reward: 157.00 - Last mean reward per episode: 5.02
# Num timesteps: 133000
# Best mean reward: 157.00 - Last mean reward per episode: 1.89
# Num timesteps: 134000
# Best mean reward: 157.00 - Last mean reward per episode: 8.18
# Num timesteps: 135000
# Best mean reward: 157.00 - Last mean reward per episode: -22.82
# Num timesteps: 136000
# Best mean reward: 157.00 - Last mean reward per episode: -31.96
# Num timesteps: 137000
# Best mean reward: 157.00 - Last mean reward per episode: -28.37
# Num timesteps: 138000
# Best mean reward: 157.00 - Last mean reward per episode: -34.48
# Num timesteps: 139000
# Best mean reward: 157.00 - Last mean reward per episode: -65.76
# Num timesteps: 140000
# Best mean reward: 157.00 - Last mean reward per episode: -43.12
# Num timesteps: 141000
# Best mean reward: 157.00 - Last mean reward per episode: -70.17
# Num timesteps: 142000
# Best mean reward: 157.00 - Last mean reward per episode: -95.55
# Num timesteps: 143000
# Best mean reward: 157.00 - Last mean reward per episode: -90.61
# Num timesteps: 144000
# Best mean reward: 157.00 - Last mean reward per episode: -85.10
# Num timesteps: 145000
# Best mean reward: 157.00 - Last mean reward per episode: -59.00
# Num timesteps: 146000
# Best mean reward: 157.00 - Last mean reward per episode: -65.63
# Num timesteps: 147000
# Best mean reward: 157.00 - Last mean reward per episode: -85.61
# Num timesteps: 148000
# Best mean reward: 157.00 - Last mean reward per episode: -49.11
# Num timesteps: 149000
# Best mean reward: 157.00 - Last mean reward per episode: -74.38
# Num timesteps: 150000
# Best mean reward: 157.00 - Last mean reward per episode: -61.44
# Num timesteps: 151000
# Best mean reward: 157.00 - Last mean reward per episode: -70.29
# Num timesteps: 152000
# Best mean reward: 157.00 - Last mean reward per episode: -113.59
# Num timesteps: 153000
# Best mean reward: 157.00 - Last mean reward per episode: -145.34
# Num timesteps: 154000
# Best mean reward: 157.00 - Last mean reward per episode: -103.44
# Num timesteps: 155000
# Best mean reward: 157.00 - Last mean reward per episode: -104.11
# Num timesteps: 156000
# Best mean reward: 157.00 - Last mean reward per episode: -73.07
# Num timesteps: 157000
# Best mean reward: 157.00 - Last mean reward per episode: -90.50
# Num timesteps: 158000
# Best mean reward: 157.00 - Last mean reward per episode: -99.75
# Num timesteps: 159000
# Best mean reward: 157.00 - Last mean reward per episode: -62.52
# Num timesteps: 160000
# Best mean reward: 157.00 - Last mean reward per episode: -82.02
# Num timesteps: 161000
# Best mean reward: 157.00 - Last mean reward per episode: -54.52
# Num timesteps: 162000
# Best mean reward: 157.00 - Last mean reward per episode: -22.91
# Num timesteps: 163000
# Best mean reward: 157.00 - Last mean reward per episode: -30.59
# Num timesteps: 164000
# Best mean reward: 157.00 - Last mean reward per episode: 16.11
# Num timesteps: 165000
# Best mean reward: 157.00 - Last mean reward per episode: 30.06
# Num timesteps: 166000
# Best mean reward: 157.00 - Last mean reward per episode: 58.14
# Num timesteps: 167000
# Best mean reward: 157.00 - Last mean reward per episode: 60.13
# Num timesteps: 168000
# Best mean reward: 157.00 - Last mean reward per episode: 84.41
# Num timesteps: 169000
# Best mean reward: 157.00 - Last mean reward per episode: 72.49
# Num timesteps: 170000
# Best mean reward: 157.00 - Last mean reward per episode: 100.41
# Num timesteps: 171000
# Best mean reward: 157.00 - Last mean reward per episode: 99.14
# Num timesteps: 172000
# Best mean reward: 157.00 - Last mean reward per episode: 100.24
# Num timesteps: 173000
# Best mean reward: 157.00 - Last mean reward per episode: 126.66
# Num timesteps: 174000
# Best mean reward: 157.00 - Last mean reward per episode: 133.66
# Num timesteps: 175000
# Best mean reward: 157.00 - Last mean reward per episode: 145.20
# Num timesteps: 176000
# Best mean reward: 157.00 - Last mean reward per episode: 156.75
# Num timesteps: 177000
# Best mean reward: 157.00 - Last mean reward per episode: 190.06
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 178000
# Best mean reward: 190.06 - Last mean reward per episode: 193.64
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 179000
# Best mean reward: 193.64 - Last mean reward per episode: 197.05
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 180000
# Best mean reward: 197.05 - Last mean reward per episode: 199.85
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 181000
# Best mean reward: 199.85 - Last mean reward per episode: 215.08
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 182000
# Best mean reward: 215.08 - Last mean reward per episode: 178.24
# Num timesteps: 183000
# Best mean reward: 215.08 - Last mean reward per episode: 152.81
# Num timesteps: 184000
# Best mean reward: 215.08 - Last mean reward per episode: 160.98
# Num timesteps: 185000
# Best mean reward: 215.08 - Last mean reward per episode: 156.98
# Num timesteps: 186000
# Best mean reward: 215.08 - Last mean reward per episode: 120.47
# Num timesteps: 187000
# Best mean reward: 215.08 - Last mean reward per episode: 135.99
# Num timesteps: 188000
# Best mean reward: 215.08 - Last mean reward per episode: 135.41
# Num timesteps: 189000
# Best mean reward: 215.08 - Last mean reward per episode: 98.53
# Num timesteps: 190000
# Best mean reward: 215.08 - Last mean reward per episode: 70.62
# Num timesteps: 191000
# Best mean reward: 215.08 - Last mean reward per episode: 45.94
# Num timesteps: 192000
# Best mean reward: 215.08 - Last mean reward per episode: 26.29
# Num timesteps: 193000
# Best mean reward: 215.08 - Last mean reward per episode: -5.57
# Num timesteps: 194000
# Best mean reward: 215.08 - Last mean reward per episode: -22.56
# Num timesteps: 195000
# Best mean reward: 215.08 - Last mean reward per episode: -64.96
# Num timesteps: 196000
# Best mean reward: 215.08 - Last mean reward per episode: -86.49
# Num timesteps: 197000
# Best mean reward: 215.08 - Last mean reward per episode: -64.53
# Num timesteps: 198000
# Best mean reward: 215.08 - Last mean reward per episode: -43.72
# Num timesteps: 199000
# Best mean reward: 215.08 - Last mean reward per episode: -45.25
# Num timesteps: 200000
# Best mean reward: 215.08 - Last mean reward per episode: -50.61
# Num timesteps: 201000
# Best mean reward: 215.08 - Last mean reward per episode: -13.70
# Num timesteps: 202000
# Best mean reward: 215.08 - Last mean reward per episode: -67.92
# Num timesteps: 203000
# Best mean reward: 215.08 - Last mean reward per episode: -75.93
# Num timesteps: 204000
# Best mean reward: 215.08 - Last mean reward per episode: -18.26
# Num timesteps: 205000
# Best mean reward: 215.08 - Last mean reward per episode: 3.06
# Num timesteps: 206000
# Best mean reward: 215.08 - Last mean reward per episode: 60.69
# Num timesteps: 207000
# Best mean reward: 215.08 - Last mean reward per episode: 142.68
# Num timesteps: 208000
# Best mean reward: 215.08 - Last mean reward per episode: 131.33
# Num timesteps: 209000
# Best mean reward: 215.08 - Last mean reward per episode: 99.23
# Num timesteps: 210000
# Best mean reward: 215.08 - Last mean reward per episode: 76.14
# Num timesteps: 211000
# Best mean reward: 215.08 - Last mean reward per episode: 78.47
# Num timesteps: 212000
# Best mean reward: 215.08 - Last mean reward per episode: 68.02
# Num timesteps: 213000
# Best mean reward: 215.08 - Last mean reward per episode: 99.06
# Num timesteps: 214000
# Best mean reward: 215.08 - Last mean reward per episode: 42.83
# Num timesteps: 215000
# Best mean reward: 215.08 - Last mean reward per episode: 11.77
# Num timesteps: 216000
# Best mean reward: 215.08 - Last mean reward per episode: 11.77
# Num timesteps: 217000
# Best mean reward: 215.08 - Last mean reward per episode: -26.73
# Num timesteps: 218000
# Best mean reward: 215.08 - Last mean reward per episode: -42.66
# Num timesteps: 219000
# Best mean reward: 215.08 - Last mean reward per episode: -60.72
# Num timesteps: 220000
# Best mean reward: 215.08 - Last mean reward per episode: -63.85
# Num timesteps: 221000
# Best mean reward: 215.08 - Last mean reward per episode: -36.84
# Num timesteps: 222000
# Best mean reward: 215.08 - Last mean reward per episode: -54.81
# Num timesteps: 223000
# Best mean reward: 215.08 - Last mean reward per episode: -41.87
# Num timesteps: 224000
# Best mean reward: 215.08 - Last mean reward per episode: -25.71
# Num timesteps: 225000
# Best mean reward: 215.08 - Last mean reward per episode: -15.09
# Num timesteps: 226000
# Best mean reward: 215.08 - Last mean reward per episode: 22.61
# Num timesteps: 227000
# Best mean reward: 215.08 - Last mean reward per episode: 62.03
# Num timesteps: 228000
# Best mean reward: 215.08 - Last mean reward per episode: 56.17
# Num timesteps: 229000
# Best mean reward: 215.08 - Last mean reward per episode: 81.93
# Num timesteps: 230000
# Best mean reward: 215.08 - Last mean reward per episode: 99.97
# Num timesteps: 231000
# Best mean reward: 215.08 - Last mean reward per episode: 88.28
# Num timesteps: 232000
# Best mean reward: 215.08 - Last mean reward per episode: 104.98
# Num timesteps: 233000
# Best mean reward: 215.08 - Last mean reward per episode: 108.98
# Num timesteps: 234000
# Best mean reward: 215.08 - Last mean reward per episode: 131.12
# Num timesteps: 235000
# Best mean reward: 215.08 - Last mean reward per episode: 131.98
# Num timesteps: 236000
# Best mean reward: 215.08 - Last mean reward per episode: 139.32
# Num timesteps: 237000
# Best mean reward: 215.08 - Last mean reward per episode: 155.31
# Num timesteps: 238000
# Best mean reward: 215.08 - Last mean reward per episode: 176.73
# Num timesteps: 239000
# Best mean reward: 215.08 - Last mean reward per episode: 189.41
# Num timesteps: 240000
# Best mean reward: 215.08 - Last mean reward per episode: 187.50
# Num timesteps: 241000
# Best mean reward: 215.08 - Last mean reward per episode: 194.50
# Num timesteps: 242000
# Best mean reward: 215.08 - Last mean reward per episode: 197.94
# Num timesteps: 243000
# Best mean reward: 215.08 - Last mean reward per episode: 195.64
# Num timesteps: 244000
# Best mean reward: 215.08 - Last mean reward per episode: 200.78
# Num timesteps: 245000
# Best mean reward: 215.08 - Last mean reward per episode: 215.42
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 246000
# Best mean reward: 215.42 - Last mean reward per episode: 197.14
# Num timesteps: 247000
# Best mean reward: 215.42 - Last mean reward per episode: 180.75
# Num timesteps: 248000
# Best mean reward: 215.42 - Last mean reward per episode: 211.07
# Num timesteps: 249000
# Best mean reward: 215.42 - Last mean reward per episode: 202.83
# Num timesteps: 250000
# Best mean reward: 215.42 - Last mean reward per episode: 198.57
# Num timesteps: 251000
# Best mean reward: 215.42 - Last mean reward per episode: 250.73
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 252000
# Best mean reward: 250.73 - Last mean reward per episode: 248.72
# Num timesteps: 253000
# Best mean reward: 250.73 - Last mean reward per episode: 242.41
# Num timesteps: 254000
# Best mean reward: 250.73 - Last mean reward per episode: 152.72
# Num timesteps: 255000
# Best mean reward: 250.73 - Last mean reward per episode: 133.43
# Num timesteps: 256000
# Best mean reward: 250.73 - Last mean reward per episode: 138.69
# Num timesteps: 257000
# Best mean reward: 250.73 - Last mean reward per episode: 139.07
# Num timesteps: 258000
# Best mean reward: 250.73 - Last mean reward per episode: 138.65
# Num timesteps: 259000
# Best mean reward: 250.73 - Last mean reward per episode: 112.82
# Num timesteps: 260000
# Best mean reward: 250.73 - Last mean reward per episode: 87.18
# Num timesteps: 261000
# Best mean reward: 250.73 - Last mean reward per episode: 93.09
# Num timesteps: 262000
# Best mean reward: 250.73 - Last mean reward per episode: 93.47
# Num timesteps: 263000
# Best mean reward: 250.73 - Last mean reward per episode: 76.27
# Num timesteps: 264000
# Best mean reward: 250.73 - Last mean reward per episode: 147.34
# Num timesteps: 265000
# Best mean reward: 250.73 - Last mean reward per episode: 140.11
# Num timesteps: 266000
# Best mean reward: 250.73 - Last mean reward per episode: 137.57
# Num timesteps: 267000
# Best mean reward: 250.73 - Last mean reward per episode: 130.23
# Num timesteps: 268000
# Best mean reward: 250.73 - Last mean reward per episode: 150.40
# Num timesteps: 269000
# Best mean reward: 250.73 - Last mean reward per episode: 154.29
# Num timesteps: 270000
# Best mean reward: 250.73 - Last mean reward per episode: 196.77
# Num timesteps: 271000
# Best mean reward: 250.73 - Last mean reward per episode: 196.40
# Num timesteps: 272000
# Best mean reward: 250.73 - Last mean reward per episode: 200.93
# Num timesteps: 273000
# Best mean reward: 250.73 - Last mean reward per episode: 224.88
# Num timesteps: 274000
# Best mean reward: 250.73 - Last mean reward per episode: 241.14
# Num timesteps: 275000
# Best mean reward: 250.73 - Last mean reward per episode: 248.65
# Num timesteps: 276000
# Best mean reward: 250.73 - Last mean reward per episode: 251.49
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 277000
# Best mean reward: 251.49 - Last mean reward per episode: 248.98
# Num timesteps: 278000
# Best mean reward: 251.49 - Last mean reward per episode: 227.76
# Num timesteps: 279000
# Best mean reward: 251.49 - Last mean reward per episode: 232.59
# Num timesteps: 280000
# Best mean reward: 251.49 - Last mean reward per episode: 204.79
# Num timesteps: 281000
# Best mean reward: 251.49 - Last mean reward per episode: 212.53
# Num timesteps: 282000
# Best mean reward: 251.49 - Last mean reward per episode: 209.64
# Num timesteps: 283000
# Best mean reward: 251.49 - Last mean reward per episode: 192.98
# Num timesteps: 284000
# Best mean reward: 251.49 - Last mean reward per episode: 192.43
# Num timesteps: 285000
# Best mean reward: 251.49 - Last mean reward per episode: 209.81
# Num timesteps: 286000
# Best mean reward: 251.49 - Last mean reward per episode: 232.81
# Num timesteps: 287000
# Best mean reward: 251.49 - Last mean reward per episode: 208.81
# Num timesteps: 288000
# Best mean reward: 251.49 - Last mean reward per episode: 220.03
# Num timesteps: 289000
# Best mean reward: 251.49 - Last mean reward per episode: 243.46
# Num timesteps: 290000
# Best mean reward: 251.49 - Last mean reward per episode: 261.27
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 291000
# Best mean reward: 261.27 - Last mean reward per episode: 209.54
# Num timesteps: 292000
# Best mean reward: 261.27 - Last mean reward per episode: 212.15
# Num timesteps: 293000
# Best mean reward: 261.27 - Last mean reward per episode: 212.51
# Num timesteps: 294000
# Best mean reward: 261.27 - Last mean reward per episode: 188.24
# Num timesteps: 295000
# Best mean reward: 261.27 - Last mean reward per episode: 163.35
# Num timesteps: 296000
# Best mean reward: 261.27 - Last mean reward per episode: 149.69
# Num timesteps: 297000
# Best mean reward: 261.27 - Last mean reward per episode: 131.87
# Num timesteps: 298000
# Best mean reward: 261.27 - Last mean reward per episode: 135.32
# Num timesteps: 299000
# Best mean reward: 261.27 - Last mean reward per episode: 129.44
# Num timesteps: 300000
# Best mean reward: 261.27 - Last mean reward per episode: 136.57
# Num timesteps: 301000
# Best mean reward: 261.27 - Last mean reward per episode: 145.31
# Num timesteps: 302000
# Best mean reward: 261.27 - Last mean reward per episode: 166.66
# Num timesteps: 303000
# Best mean reward: 261.27 - Last mean reward per episode: 200.59
# Num timesteps: 304000
# Best mean reward: 261.27 - Last mean reward per episode: 220.18
# Num timesteps: 305000
# Best mean reward: 261.27 - Last mean reward per episode: 243.79
# Num timesteps: 306000
# Best mean reward: 261.27 - Last mean reward per episode: 255.79
# Num timesteps: 307000
# Best mean reward: 261.27 - Last mean reward per episode: 276.33
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 308000
# Best mean reward: 276.33 - Last mean reward per episode: 260.17
# Num timesteps: 309000
# Best mean reward: 276.33 - Last mean reward per episode: 271.03
# Num timesteps: 310000
# Best mean reward: 276.33 - Last mean reward per episode: 280.23
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 311000
# Best mean reward: 280.23 - Last mean reward per episode: 281.04
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 312000
# Best mean reward: 281.04 - Last mean reward per episode: 294.14
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 313000
# Best mean reward: 294.14 - Last mean reward per episode: 291.55
# Num timesteps: 314000
# Best mean reward: 294.14 - Last mean reward per episode: 277.07
# Num timesteps: 315000
# Best mean reward: 294.14 - Last mean reward per episode: 266.36
# Num timesteps: 316000
# Best mean reward: 294.14 - Last mean reward per episode: 269.24
# Num timesteps: 317000
# Best mean reward: 294.14 - Last mean reward per episode: 263.01
# Num timesteps: 318000
# Best mean reward: 294.14 - Last mean reward per episode: 185.71
# Num timesteps: 319000
# Best mean reward: 294.14 - Last mean reward per episode: 197.44
# Num timesteps: 320000
# Best mean reward: 294.14 - Last mean reward per episode: 164.56
# Num timesteps: 321000
# Best mean reward: 294.14 - Last mean reward per episode: 172.77
# Num timesteps: 322000
# Best mean reward: 294.14 - Last mean reward per episode: 156.63
# Num timesteps: 323000
# Best mean reward: 294.14 - Last mean reward per episode: 130.74
# Num timesteps: 324000
# Best mean reward: 294.14 - Last mean reward per episode: 108.41
# Num timesteps: 325000
# Best mean reward: 294.14 - Last mean reward per episode: 97.30
# Num timesteps: 326000
# Best mean reward: 294.14 - Last mean reward per episode: 114.00
# Num timesteps: 327000
# Best mean reward: 294.14 - Last mean reward per episode: 115.76
# Num timesteps: 328000
# Best mean reward: 294.14 - Last mean reward per episode: 123.35
# Num timesteps: 329000
# Best mean reward: 294.14 - Last mean reward per episode: 134.26
# Num timesteps: 330000
# Best mean reward: 294.14 - Last mean reward per episode: 188.64
# Num timesteps: 331000
# Best mean reward: 294.14 - Last mean reward per episode: 167.18
# Num timesteps: 332000
# Best mean reward: 294.14 - Last mean reward per episode: 171.32
# Num timesteps: 333000
# Best mean reward: 294.14 - Last mean reward per episode: 136.66
# Num timesteps: 334000
# Best mean reward: 294.14 - Last mean reward per episode: 121.64
# Num timesteps: 335000
# Best mean reward: 294.14 - Last mean reward per episode: 109.64
# Num timesteps: 336000
# Best mean reward: 294.14 - Last mean reward per episode: 112.28
# Num timesteps: 337000
# Best mean reward: 294.14 - Last mean reward per episode: 127.72
# Num timesteps: 338000
# Best mean reward: 294.14 - Last mean reward per episode: 136.43
# Num timesteps: 339000
# Best mean reward: 294.14 - Last mean reward per episode: 137.04
# Num timesteps: 340000
# Best mean reward: 294.14 - Last mean reward per episode: 117.33
# Num timesteps: 341000
# Best mean reward: 294.14 - Last mean reward per episode: 93.00
# Num timesteps: 342000
# Best mean reward: 294.14 - Last mean reward per episode: 99.13
# Num timesteps: 343000
# Best mean reward: 294.14 - Last mean reward per episode: 108.69
# Num timesteps: 344000
# Best mean reward: 294.14 - Last mean reward per episode: 122.24
# Num timesteps: 345000
# Best mean reward: 294.14 - Last mean reward per episode: 122.34
# Num timesteps: 346000
# Best mean reward: 294.14 - Last mean reward per episode: 148.69
# Num timesteps: 347000
# Best mean reward: 294.14 - Last mean reward per episode: 168.31
# Num timesteps: 348000
# Best mean reward: 294.14 - Last mean reward per episode: 193.21
# Num timesteps: 349000
# Best mean reward: 294.14 - Last mean reward per episode: 183.91
# Num timesteps: 350000
# Best mean reward: 294.14 - Last mean reward per episode: 184.65
# Num timesteps: 351000
# Best mean reward: 294.14 - Last mean reward per episode: 217.41
# Num timesteps: 352000
# Best mean reward: 294.14 - Last mean reward per episode: 230.05
# Num timesteps: 353000
# Best mean reward: 294.14 - Last mean reward per episode: 257.87
# Num timesteps: 354000
# Best mean reward: 294.14 - Last mean reward per episode: 251.96
# Num timesteps: 355000
# Best mean reward: 294.14 - Last mean reward per episode: 260.11
# Num timesteps: 356000
# Best mean reward: 294.14 - Last mean reward per episode: 252.85
# Num timesteps: 357000
# Best mean reward: 294.14 - Last mean reward per episode: 239.49
# Num timesteps: 358000
# Best mean reward: 294.14 - Last mean reward per episode: 252.70
# Num timesteps: 359000
# Best mean reward: 294.14 - Last mean reward per episode: 224.17
# Num timesteps: 360000
# Best mean reward: 294.14 - Last mean reward per episode: 236.98
# Num timesteps: 361000
# Best mean reward: 294.14 - Last mean reward per episode: 247.89
# Num timesteps: 362000
# Best mean reward: 294.14 - Last mean reward per episode: 227.78
# Num timesteps: 363000
# Best mean reward: 294.14 - Last mean reward per episode: 205.99
# Num timesteps: 364000
# Best mean reward: 294.14 - Last mean reward per episode: 156.68
# Num timesteps: 365000
# Best mean reward: 294.14 - Last mean reward per episode: 171.01
# Num timesteps: 366000
# Best mean reward: 294.14 - Last mean reward per episode: 182.57
# Num timesteps: 367000
# Best mean reward: 294.14 - Last mean reward per episode: 191.05
# Num timesteps: 368000
# Best mean reward: 294.14 - Last mean reward per episode: 147.72
# Num timesteps: 369000
# Best mean reward: 294.14 - Last mean reward per episode: 168.25
# Num timesteps: 370000
# Best mean reward: 294.14 - Last mean reward per episode: 164.25
# Num timesteps: 371000
# Best mean reward: 294.14 - Last mean reward per episode: 184.60
# Num timesteps: 372000
# Best mean reward: 294.14 - Last mean reward per episode: 185.68
# Num timesteps: 373000
# Best mean reward: 294.14 - Last mean reward per episode: 151.74
# Num timesteps: 374000
# Best mean reward: 294.14 - Last mean reward per episode: 139.77
# Num timesteps: 375000
# Best mean reward: 294.14 - Last mean reward per episode: 136.19
# Num timesteps: 376000
# Best mean reward: 294.14 - Last mean reward per episode: 101.81
# Num timesteps: 377000
# Best mean reward: 294.14 - Last mean reward per episode: 100.25
# Num timesteps: 378000
# Best mean reward: 294.14 - Last mean reward per episode: 121.54
# Num timesteps: 379000
# Best mean reward: 294.14 - Last mean reward per episode: 108.35
# Num timesteps: 380000
# Best mean reward: 294.14 - Last mean reward per episode: 81.51
# Num timesteps: 381000
# Best mean reward: 294.14 - Last mean reward per episode: 152.00
# Num timesteps: 382000
# Best mean reward: 294.14 - Last mean reward per episode: 93.47
# Num timesteps: 383000
# Best mean reward: 294.14 - Last mean reward per episode: 63.58
# Num timesteps: 384000
# Best mean reward: 294.14 - Last mean reward per episode: 58.54
# Num timesteps: 385000
# Best mean reward: 294.14 - Last mean reward per episode: 54.99
# Num timesteps: 386000
# Best mean reward: 294.14 - Last mean reward per episode: 37.45
# Num timesteps: 387000
# Best mean reward: 294.14 - Last mean reward per episode: 68.71
# Num timesteps: 388000
# Best mean reward: 294.14 - Last mean reward per episode: 32.79
# Num timesteps: 389000
# Best mean reward: 294.14 - Last mean reward per episode: 29.50
# Num timesteps: 390000
# Best mean reward: 294.14 - Last mean reward per episode: 42.88
# Num timesteps: 391000
# Best mean reward: 294.14 - Last mean reward per episode: 51.15
# Num timesteps: 392000
# Best mean reward: 294.14 - Last mean reward per episode: 62.35
# Num timesteps: 393000
# Best mean reward: 294.14 - Last mean reward per episode: 37.27
# Num timesteps: 394000
# Best mean reward: 294.14 - Last mean reward per episode: 41.21
# Num timesteps: 395000
# Best mean reward: 294.14 - Last mean reward per episode: 35.83
# Num timesteps: 396000
# Best mean reward: 294.14 - Last mean reward per episode: 41.37
# Num timesteps: 397000
# Best mean reward: 294.14 - Last mean reward per episode: -10.25
# Num timesteps: 398000
# Best mean reward: 294.14 - Last mean reward per episode: 19.37
# Num timesteps: 399000
# Best mean reward: 294.14 - Last mean reward per episode: 65.13
# Num timesteps: 400000
# Best mean reward: 294.14 - Last mean reward per episode: 38.99
# Num timesteps: 401000
# Best mean reward: 294.14 - Last mean reward per episode: 65.02
# Num timesteps: 402000
# Best mean reward: 294.14 - Last mean reward per episode: 33.77
# Num timesteps: 403000
# Best mean reward: 294.14 - Last mean reward per episode: 4.68
# Num timesteps: 404000
# Best mean reward: 294.14 - Last mean reward per episode: -39.47
# Num timesteps: 405000
# Best mean reward: 294.14 - Last mean reward per episode: -10.71
# Num timesteps: 406000
# Best mean reward: 294.14 - Last mean reward per episode: -10.10
# Num timesteps: 407000
# Best mean reward: 294.14 - Last mean reward per episode: -10.10
# Num timesteps: 408000
# Best mean reward: 294.14 - Last mean reward per episode: -142.01
# Num timesteps: 409000
# Best mean reward: 294.14 - Last mean reward per episode: -120.09
# Num timesteps: 410000
# Best mean reward: 294.14 - Last mean reward per episode: -138.24
# Num timesteps: 411000
# Best mean reward: 294.14 - Last mean reward per episode: -142.18
# Num timesteps: 412000
# Best mean reward: 294.14 - Last mean reward per episode: -127.25
# Num timesteps: 413000
# Best mean reward: 294.14 - Last mean reward per episode: -129.54
# Num timesteps: 414000
# Best mean reward: 294.14 - Last mean reward per episode: -161.86
# Num timesteps: 415000
# Best mean reward: 294.14 - Last mean reward per episode: -123.58
# Num timesteps: 416000
# Best mean reward: 294.14 - Last mean reward per episode: -140.25
# Num timesteps: 417000
# Best mean reward: 294.14 - Last mean reward per episode: -146.78
# Num timesteps: 418000
# Best mean reward: 294.14 - Last mean reward per episode: -126.12
# Num timesteps: 419000
# Best mean reward: 294.14 - Last mean reward per episode: -142.43
# Num timesteps: 420000
# Best mean reward: 294.14 - Last mean reward per episode: -67.60
# Num timesteps: 421000
# Best mean reward: 294.14 - Last mean reward per episode: -37.61
# Num timesteps: 422000
# Best mean reward: 294.14 - Last mean reward per episode: -71.57
# Num timesteps: 423000
# Best mean reward: 294.14 - Last mean reward per episode: -82.55
# Num timesteps: 424000
# Best mean reward: 294.14 - Last mean reward per episode: 49.56
# Num timesteps: 425000
# Best mean reward: 294.14 - Last mean reward per episode: 69.54
# Num timesteps: 426000
# Best mean reward: 294.14 - Last mean reward per episode: 89.37
# Num timesteps: 427000
# Best mean reward: 294.14 - Last mean reward per episode: 120.39
# Num timesteps: 428000
# Best mean reward: 294.14 - Last mean reward per episode: 149.16
# Num timesteps: 429000
# Best mean reward: 294.14 - Last mean reward per episode: 163.38
# Num timesteps: 430000
# Best mean reward: 294.14 - Last mean reward per episode: 133.18
# Num timesteps: 431000
# Best mean reward: 294.14 - Last mean reward per episode: 137.31
# Num timesteps: 432000
# Best mean reward: 294.14 - Last mean reward per episode: 142.23
# Num timesteps: 433000
# Best mean reward: 294.14 - Last mean reward per episode: 155.56
# Num timesteps: 434000
# Best mean reward: 294.14 - Last mean reward per episode: 147.97
# Num timesteps: 435000
# Best mean reward: 294.14 - Last mean reward per episode: 150.67
# Num timesteps: 436000
# Best mean reward: 294.14 - Last mean reward per episode: 149.72
# Num timesteps: 437000
# Best mean reward: 294.14 - Last mean reward per episode: 120.45
# Num timesteps: 438000
# Best mean reward: 294.14 - Last mean reward per episode: 119.73
# Num timesteps: 439000
# Best mean reward: 294.14 - Last mean reward per episode: 108.07
# Num timesteps: 440000
# Best mean reward: 294.14 - Last mean reward per episode: 83.88
# Num timesteps: 441000
# Best mean reward: 294.14 - Last mean reward per episode: 81.56
# Num timesteps: 442000
# Best mean reward: 294.14 - Last mean reward per episode: 98.56
# Num timesteps: 443000
# Best mean reward: 294.14 - Last mean reward per episode: 79.71
# Num timesteps: 444000
# Best mean reward: 294.14 - Last mean reward per episode: 69.75
# Num timesteps: 445000
# Best mean reward: 294.14 - Last mean reward per episode: 76.43
# Num timesteps: 446000
# Best mean reward: 294.14 - Last mean reward per episode: 80.36
# Num timesteps: 447000
# Best mean reward: 294.14 - Last mean reward per episode: 72.95
# Num timesteps: 448000
# Best mean reward: 294.14 - Last mean reward per episode: 78.05
# Num timesteps: 449000
# Best mean reward: 294.14 - Last mean reward per episode: 95.36
# Num timesteps: 450000
# Best mean reward: 294.14 - Last mean reward per episode: 112.52
# Num timesteps: 451000
# Best mean reward: 294.14 - Last mean reward per episode: 131.49
# Num timesteps: 452000
# Best mean reward: 294.14 - Last mean reward per episode: 131.58
# Num timesteps: 453000
# Best mean reward: 294.14 - Last mean reward per episode: 88.72
# Num timesteps: 454000
# Best mean reward: 294.14 - Last mean reward per episode: 93.53
# Num timesteps: 455000
# Best mean reward: 294.14 - Last mean reward per episode: 99.78
# Num timesteps: 456000
# Best mean reward: 294.14 - Last mean reward per episode: 114.60
# Num timesteps: 457000
# Best mean reward: 294.14 - Last mean reward per episode: 120.20
# Num timesteps: 458000
# Best mean reward: 294.14 - Last mean reward per episode: 129.71
# Num timesteps: 459000
# Best mean reward: 294.14 - Last mean reward per episode: 143.14
# Num timesteps: 460000
# Best mean reward: 294.14 - Last mean reward per episode: 167.42
# Num timesteps: 461000
# Best mean reward: 294.14 - Last mean reward per episode: 187.10
# Num timesteps: 462000
# Best mean reward: 294.14 - Last mean reward per episode: 172.07
# Num timesteps: 463000
# Best mean reward: 294.14 - Last mean reward per episode: 135.40
# Num timesteps: 464000
# Best mean reward: 294.14 - Last mean reward per episode: 140.61
# Num timesteps: 465000
# Best mean reward: 294.14 - Last mean reward per episode: 202.10
# Num timesteps: 466000
# Best mean reward: 294.14 - Last mean reward per episode: 191.76
# Num timesteps: 467000
# Best mean reward: 294.14 - Last mean reward per episode: 193.72
# Num timesteps: 468000
# Best mean reward: 294.14 - Last mean reward per episode: 174.55
# Num timesteps: 469000
# Best mean reward: 294.14 - Last mean reward per episode: 181.46
# Num timesteps: 470000
# Best mean reward: 294.14 - Last mean reward per episode: 199.65
# Num timesteps: 471000
# Best mean reward: 294.14 - Last mean reward per episode: 165.12
# Num timesteps: 472000
# Best mean reward: 294.14 - Last mean reward per episode: 155.65
# Num timesteps: 473000
# Best mean reward: 294.14 - Last mean reward per episode: 145.93
# Num timesteps: 474000
# Best mean reward: 294.14 - Last mean reward per episode: 163.07
# Num timesteps: 475000
# Best mean reward: 294.14 - Last mean reward per episode: 138.15
# Num timesteps: 476000
# Best mean reward: 294.14 - Last mean reward per episode: 139.95
# Num timesteps: 477000
# Best mean reward: 294.14 - Last mean reward per episode: 122.11
# Num timesteps: 478000
# Best mean reward: 294.14 - Last mean reward per episode: 182.55
# Num timesteps: 479000
# Best mean reward: 294.14 - Last mean reward per episode: 173.08
# Num timesteps: 480000
# Best mean reward: 294.14 - Last mean reward per episode: 173.08
# Num timesteps: 481000
# Best mean reward: 294.14 - Last mean reward per episode: 43.65
# Num timesteps: 482000
# Best mean reward: 294.14 - Last mean reward per episode: 61.44
# Num timesteps: 483000
# Best mean reward: 294.14 - Last mean reward per episode: 59.85
# Num timesteps: 484000
# Best mean reward: 294.14 - Last mean reward per episode: 36.85
# Num timesteps: 485000
# Best mean reward: 294.14 - Last mean reward per episode: 60.29
# Num timesteps: 486000
# Best mean reward: 294.14 - Last mean reward per episode: 52.70
# Num timesteps: 487000
# Best mean reward: 294.14 - Last mean reward per episode: 86.44
# Num timesteps: 488000
# Best mean reward: 294.14 - Last mean reward per episode: 81.26
# Num timesteps: 489000
# Best mean reward: 294.14 - Last mean reward per episode: -13.87
# Num timesteps: 490000
# Best mean reward: 294.14 - Last mean reward per episode: -21.27
# Num timesteps: 491000
# Best mean reward: 294.14 - Last mean reward per episode: -25.90
# Num timesteps: 492000
# Best mean reward: 294.14 - Last mean reward per episode: -58.17
# Num timesteps: 493000
# Best mean reward: 294.14 - Last mean reward per episode: -74.95
# Num timesteps: 494000
# Best mean reward: 294.14 - Last mean reward per episode: -87.89
# Num timesteps: 495000
# Best mean reward: 294.14 - Last mean reward per episode: -70.45
# Num timesteps: 496000
# Best mean reward: 294.14 - Last mean reward per episode: -95.16
# Num timesteps: 497000
# Best mean reward: 294.14 - Last mean reward per episode: 3.06
# Num timesteps: 498000
# Best mean reward: 294.14 - Last mean reward per episode: -6.17
# Num timesteps: 499000
# Best mean reward: 294.14 - Last mean reward per episode: -26.95
# Num timesteps: 500000
# Best mean reward: 294.14 - Last mean reward per episode: -40.26
# Num timesteps: 501000
# Best mean reward: 294.14 - Last mean reward per episode: -31.48
# Num timesteps: 502000
# Best mean reward: 294.14 - Last mean reward per episode: -34.22
# Num timesteps: 503000
# Best mean reward: 294.14 - Last mean reward per episode: -34.22
# Num timesteps: 504000
# Best mean reward: 294.14 - Last mean reward per episode: -203.84
# Num timesteps: 505000
# Best mean reward: 294.14 - Last mean reward per episode: -208.45
# Num timesteps: 506000
# Best mean reward: 294.14 - Last mean reward per episode: -215.61
# Num timesteps: 507000
# Best mean reward: 294.14 - Last mean reward per episode: -143.15
# Num timesteps: 508000
# Best mean reward: 294.14 - Last mean reward per episode: -195.30
# Num timesteps: 509000
# Best mean reward: 294.14 - Last mean reward per episode: -181.83
# Num timesteps: 510000
# Best mean reward: 294.14 - Last mean reward per episode: -196.24
# Num timesteps: 511000
# Best mean reward: 294.14 - Last mean reward per episode: -259.61
# Num timesteps: 512000
# Best mean reward: 294.14 - Last mean reward per episode: -217.56
# Num timesteps: 513000
# Best mean reward: 294.14 - Last mean reward per episode: -247.35
# Num timesteps: 514000
# Best mean reward: 294.14 - Last mean reward per episode: -238.62
# Num timesteps: 515000
# Best mean reward: 294.14 - Last mean reward per episode: -238.62
# Num timesteps: 516000
# Best mean reward: 294.14 - Last mean reward per episode: -378.06
# Num timesteps: 517000
# Best mean reward: 294.14 - Last mean reward per episode: -428.31
# Num timesteps: 518000
# Best mean reward: 294.14 - Last mean reward per episode: -413.92
# Num timesteps: 519000
# Best mean reward: 294.14 - Last mean reward per episode: -495.13
# Num timesteps: 520000
# Best mean reward: 294.14 - Last mean reward per episode: -511.12
# Num timesteps: 521000
# Best mean reward: 294.14 - Last mean reward per episode: -502.44
# ...
# Num timesteps: 636000
# Best mean reward: 294.14 - Last mean reward per episode: 139.34
# Num timesteps: 637000
# Best mean reward: 294.14 - Last mean reward per episode: 155.89
# Num timesteps: 638000
# Best mean reward: 294.14 - Last mean reward per episode: 181.26
# Num timesteps: 639000
# Best mean reward: 294.14 - Last mean reward per episode: 203.34
# Num timesteps: 640000
# Best mean reward: 294.14 - Last mean reward per episode: 212.80
# Num timesteps: 641000
# Best mean reward: 294.14 - Last mean reward per episode: 193.90
# Num timesteps: 642000
# Best mean reward: 294.14 - Last mean reward per episode: 174.64
# Num timesteps: 643000
# Best mean reward: 294.14 - Last mean reward per episode: 177.43
# Num timesteps: 644000
# Best mean reward: 294.14 - Last mean reward per episode: 224.02
# Num timesteps: 645000
# Best mean reward: 294.14 - Last mean reward per episode: 230.59
# Num timesteps: 646000
# Best mean reward: 294.14 - Last mean reward per episode: 224.53
# Num timesteps: 647000
# Best mean reward: 294.14 - Last mean reward per episode: 212.87
# Num timesteps: 648000
# Best mean reward: 294.14 - Last mean reward per episode: 225.94
# Num timesteps: 649000
# Best mean reward: 294.14 - Last mean reward per episode: 198.03
# Num timesteps: 650000
# Best mean reward: 294.14 - Last mean reward per episode: 192.36
# Num timesteps: 651000
# Best mean reward: 294.14 - Last mean reward per episode: 194.45
# Num timesteps: 652000
# Best mean reward: 294.14 - Last mean reward per episode: 196.35
# Num timesteps: 653000
# Best mean reward: 294.14 - Last mean reward per episode: 181.79
# Num timesteps: 654000
# Best mean reward: 294.14 - Last mean reward per episode: 203.56
# Num timesteps: 655000
# Best mean reward: 294.14 - Last mean reward per episode: 216.76
# Num timesteps: 656000
# Best mean reward: 294.14 - Last mean reward per episode: 224.56
# Num timesteps: 657000
# Best mean reward: 294.14 - Last mean reward per episode: 205.27
# Num timesteps: 658000
# Best mean reward: 294.14 - Last mean reward per episode: 209.77
# Num timesteps: 659000
# Best mean reward: 294.14 - Last mean reward per episode: 209.82
# Num timesteps: 660000
# Best mean reward: 294.14 - Last mean reward per episode: 238.35
# Num timesteps: 661000
# Best mean reward: 294.14 - Last mean reward per episode: 263.92
# Num timesteps: 662000
# Best mean reward: 294.14 - Last mean reward per episode: 266.84
# Num timesteps: 663000
# Best mean reward: 294.14 - Last mean reward per episode: 271.78
# Num timesteps: 664000
# Best mean reward: 294.14 - Last mean reward per episode: 256.14
# Num timesteps: 665000
# Best mean reward: 294.14 - Last mean reward per episode: 258.54
# Num timesteps: 666000
# Best mean reward: 294.14 - Last mean reward per episode: 274.41
# Num timesteps: 667000
# Best mean reward: 294.14 - Last mean reward per episode: 242.27
# Num timesteps: 668000
# Best mean reward: 294.14 - Last mean reward per episode: 232.68
# Num timesteps: 669000
# Best mean reward: 294.14 - Last mean reward per episode: 211.19
# Num timesteps: 670000
# Best mean reward: 294.14 - Last mean reward per episode: 231.54
# Num timesteps: 671000
# Best mean reward: 294.14 - Last mean reward per episode: 206.73
# Num timesteps: 672000
# Best mean reward: 294.14 - Last mean reward per episode: 204.26
# Num timesteps: 673000
# Best mean reward: 294.14 - Last mean reward per episode: 201.43
# Num timesteps: 674000
# Best mean reward: 294.14 - Last mean reward per episode: 190.97
# Num timesteps: 675000
# Best mean reward: 294.14 - Last mean reward per episode: 197.69
# Num timesteps: 676000
# Best mean reward: 294.14 - Last mean reward per episode: 208.66
# Num timesteps: 677000
# Best mean reward: 294.14 - Last mean reward per episode: 197.38
# Num timesteps: 678000
# Best mean reward: 294.14 - Last mean reward per episode: 183.78
# Num timesteps: 679000
# Best mean reward: 294.14 - Last mean reward per episode: 225.96
# Num timesteps: 680000
# Best mean reward: 294.14 - Last mean reward per episode: 200.99
# Num timesteps: 681000
# Best mean reward: 294.14 - Last mean reward per episode: 185.62
# Num timesteps: 682000
# Best mean reward: 294.14 - Last mean reward per episode: 185.62
# Num timesteps: 683000
# Best mean reward: 294.14 - Last mean reward per episode: 118.13
# Num timesteps: 684000
# Best mean reward: 294.14 - Last mean reward per episode: 115.60
# Num timesteps: 685000
# Best mean reward: 294.14 - Last mean reward per episode: 33.46
# Num timesteps: 686000
# Best mean reward: 294.14 - Last mean reward per episode: -8.52
# Num timesteps: 687000
# Best mean reward: 294.14 - Last mean reward per episode: 6.09
# Num timesteps: 688000
# Best mean reward: 294.14 - Last mean reward per episode: 6.09
# Num timesteps: 689000
# Best mean reward: 294.14 - Last mean reward per episode: -48.01
# Num timesteps: 690000
# Best mean reward: 294.14 - Last mean reward per episode: -55.36
# Num timesteps: 691000
# Best mean reward: 294.14 - Last mean reward per episode: -45.78
# Num timesteps: 692000
# Best mean reward: 294.14 - Last mean reward per episode: -69.57
# Num timesteps: 693000
# Best mean reward: 294.14 - Last mean reward per episode: -88.21
# Num timesteps: 694000
# Best mean reward: 294.14 - Last mean reward per episode: -141.85
# Num timesteps: 695000
# Best mean reward: 294.14 - Last mean reward per episode: -123.65
# Num timesteps: 696000
# Best mean reward: 294.14 - Last mean reward per episode: -105.06
# Num timesteps: 697000
# Best mean reward: 294.14 - Last mean reward per episode: -112.62
# Num timesteps: 698000
# Best mean reward: 294.14 - Last mean reward per episode: -104.75
# Num timesteps: 699000
# Best mean reward: 294.14 - Last mean reward per episode: -101.29
# Num timesteps: 700000
# Best mean reward: 294.14 - Last mean reward per episode: -28.98
# Num timesteps: 701000
# Best mean reward: 294.14 - Last mean reward per episode: -41.56
# Num timesteps: 702000
# Best mean reward: 294.14 - Last mean reward per episode: 3.16
# Num timesteps: 703000
# Best mean reward: 294.14 - Last mean reward per episode: 20.76
# Num timesteps: 704000
# Best mean reward: 294.14 - Last mean reward per episode: 31.19
# Num timesteps: 705000
# Best mean reward: 294.14 - Last mean reward per episode: 2.90
# Num timesteps: 706000
# Best mean reward: 294.14 - Last mean reward per episode: -35.68
# Num timesteps: 707000
# Best mean reward: 294.14 - Last mean reward per episode: 7.43
# Num timesteps: 708000
# Best mean reward: 294.14 - Last mean reward per episode: 5.91
# Num timesteps: 709000
# Best mean reward: 294.14 - Last mean reward per episode: -18.04
# Num timesteps: 710000
# Best mean reward: 294.14 - Last mean reward per episode: 11.71
# Num timesteps: 711000
# Best mean reward: 294.14 - Last mean reward per episode: 46.99
# Num timesteps: 712000
# Best mean reward: 294.14 - Last mean reward per episode: 32.47
# Num timesteps: 713000
# Best mean reward: 294.14 - Last mean reward per episode: 24.23
# Num timesteps: 714000
# Best mean reward: 294.14 - Last mean reward per episode: 17.04
# Num timesteps: 715000
# Best mean reward: 294.14 - Last mean reward per episode: 20.11
# Num timesteps: 716000
# Best mean reward: 294.14 - Last mean reward per episode: 15.14
# Num timesteps: 717000
# Best mean reward: 294.14 - Last mean reward per episode: 6.89
# Num timesteps: 718000
# Best mean reward: 294.14 - Last mean reward per episode: 13.15
# Num timesteps: 719000
# Best mean reward: 294.14 - Last mean reward per episode: 99.09
# Num timesteps: 720000
# Best mean reward: 294.14 - Last mean reward per episode: 112.89
# Num timesteps: 721000
# Best mean reward: 294.14 - Last mean reward per episode: 97.45
# Num timesteps: 722000
# Best mean reward: 294.14 - Last mean reward per episode: 123.89
# Num timesteps: 723000
# Best mean reward: 294.14 - Last mean reward per episode: 108.65
# Num timesteps: 724000
# Best mean reward: 294.14 - Last mean reward per episode: 124.82
# Num timesteps: 725000
# Best mean reward: 294.14 - Last mean reward per episode: 143.99
# Num timesteps: 726000
# Best mean reward: 294.14 - Last mean reward per episode: 148.65
# Num timesteps: 727000
# Best mean reward: 294.14 - Last mean reward per episode: 148.10
# Num timesteps: 728000
# Best mean reward: 294.14 - Last mean reward per episode: 150.76
# Num timesteps: 729000
# Best mean reward: 294.14 - Last mean reward per episode: 180.25
# Num timesteps: 730000
# Best mean reward: 294.14 - Last mean reward per episode: 181.61
# Num timesteps: 731000
# Best mean reward: 294.14 - Last mean reward per episode: 194.90
# Num timesteps: 732000
# Best mean reward: 294.14 - Last mean reward per episode: 206.55
# Num timesteps: 733000
# Best mean reward: 294.14 - Last mean reward per episode: 236.42
# Num timesteps: 734000
# Best mean reward: 294.14 - Last mean reward per episode: 246.14
# Num timesteps: 735000
# Best mean reward: 294.14 - Last mean reward per episode: 217.48
# Num timesteps: 736000
# Best mean reward: 294.14 - Last mean reward per episode: 225.28
# Num timesteps: 737000
# Best mean reward: 294.14 - Last mean reward per episode: 255.41
# Num timesteps: 738000
# Best mean reward: 294.14 - Last mean reward per episode: 253.18
# Num timesteps: 739000
# Best mean reward: 294.14 - Last mean reward per episode: 254.82
# Num timesteps: 740000
# Best mean reward: 294.14 - Last mean reward per episode: 256.27
# Num timesteps: 741000
# Best mean reward: 294.14 - Last mean reward per episode: 283.18
# Num timesteps: 742000
# Best mean reward: 294.14 - Last mean reward per episode: 275.96
# Num timesteps: 743000
# Best mean reward: 294.14 - Last mean reward per episode: 291.87
# Num timesteps: 744000
# Best mean reward: 294.14 - Last mean reward per episode: 278.56
# Num timesteps: 745000
# Best mean reward: 294.14 - Last mean reward per episode: 272.14
# Num timesteps: 746000
# Best mean reward: 294.14 - Last mean reward per episode: 282.82
# Num timesteps: 747000
# Best mean reward: 294.14 - Last mean reward per episode: 301.12
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 748000
# Best mean reward: 301.12 - Last mean reward per episode: 326.01
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 749000
# Best mean reward: 326.01 - Last mean reward per episode: 307.28
# Num timesteps: 750000
# Best mean reward: 326.01 - Last mean reward per episode: 260.80
# Num timesteps: 751000
# Best mean reward: 326.01 - Last mean reward per episode: 243.31
# Num timesteps: 752000
# Best mean reward: 326.01 - Last mean reward per episode: 210.05
# Num timesteps: 753000
# Best mean reward: 326.01 - Last mean reward per episode: 206.20
# Num timesteps: 754000
# Best mean reward: 326.01 - Last mean reward per episode: 215.87
# Num timesteps: 755000
# Best mean reward: 326.01 - Last mean reward per episode: 207.42
# Num timesteps: 756000
# Best mean reward: 326.01 - Last mean reward per episode: 193.36
# Num timesteps: 757000
# Best mean reward: 326.01 - Last mean reward per episode: 179.38
# Num timesteps: 758000
# Best mean reward: 326.01 - Last mean reward per episode: 136.50
# Num timesteps: 759000
# Best mean reward: 326.01 - Last mean reward per episode: 154.94
# Num timesteps: 760000
# Best mean reward: 326.01 - Last mean reward per episode: 194.18
# Num timesteps: 761000
# Best mean reward: 326.01 - Last mean reward per episode: 210.18
# Num timesteps: 762000
# Best mean reward: 326.01 - Last mean reward per episode: 206.19
# Num timesteps: 763000
# Best mean reward: 326.01 - Last mean reward per episode: 226.73
# Num timesteps: 764000
# Best mean reward: 326.01 - Last mean reward per episode: 214.33
# Num timesteps: 765000
# Best mean reward: 326.01 - Last mean reward per episode: 198.42
# Num timesteps: 766000
# Best mean reward: 326.01 - Last mean reward per episode: 215.92
# Num timesteps: 767000
# Best mean reward: 326.01 - Last mean reward per episode: 191.45
# Num timesteps: 768000
# Best mean reward: 326.01 - Last mean reward per episode: 180.41
# Num timesteps: 769000
# Best mean reward: 326.01 - Last mean reward per episode: 178.87
# Num timesteps: 770000
# Best mean reward: 326.01 - Last mean reward per episode: 181.95
# Num timesteps: 771000
# Best mean reward: 326.01 - Last mean reward per episode: 149.71
# Num timesteps: 772000
# Best mean reward: 326.01 - Last mean reward per episode: 141.48
# Num timesteps: 773000
# Best mean reward: 326.01 - Last mean reward per episode: 142.85
# Num timesteps: 774000
# Best mean reward: 326.01 - Last mean reward per episode: 141.10
# Num timesteps: 775000
# Best mean reward: 326.01 - Last mean reward per episode: 154.14
# Num timesteps: 776000
# Best mean reward: 326.01 - Last mean reward per episode: 184.52
# Num timesteps: 777000
# Best mean reward: 326.01 - Last mean reward per episode: 190.70
# Num timesteps: 778000
# Best mean reward: 326.01 - Last mean reward per episode: 228.92
# Num timesteps: 779000
# Best mean reward: 326.01 - Last mean reward per episode: 252.91
# Num timesteps: 780000
# Best mean reward: 326.01 - Last mean reward per episode: 258.23
# Num timesteps: 781000
# Best mean reward: 326.01 - Last mean reward per episode: 290.72
# Num timesteps: 782000
# Best mean reward: 326.01 - Last mean reward per episode: 278.80
# Num timesteps: 783000
# Best mean reward: 326.01 - Last mean reward per episode: 273.46
# Num timesteps: 784000
# Best mean reward: 326.01 - Last mean reward per episode: 284.61
# Num timesteps: 785000
# Best mean reward: 326.01 - Last mean reward per episode: 272.15
# Num timesteps: 786000
# Best mean reward: 326.01 - Last mean reward per episode: 271.59
# Num timesteps: 787000
# Best mean reward: 326.01 - Last mean reward per episode: 257.89
# Num timesteps: 788000
# Best mean reward: 326.01 - Last mean reward per episode: 241.20
# Num timesteps: 789000
# Best mean reward: 326.01 - Last mean reward per episode: 236.55
# Num timesteps: 790000
# Best mean reward: 326.01 - Last mean reward per episode: 258.47
# Num timesteps: 791000
# Best mean reward: 326.01 - Last mean reward per episode: 266.20
# Num timesteps: 792000
# Best mean reward: 326.01 - Last mean reward per episode: 266.77
# Num timesteps: 793000
# Best mean reward: 326.01 - Last mean reward per episode: 269.32
# Num timesteps: 794000
# Best mean reward: 326.01 - Last mean reward per episode: 262.29
# Num timesteps: 795000
# Best mean reward: 326.01 - Last mean reward per episode: 280.62
# Num timesteps: 796000
# Best mean reward: 326.01 - Last mean reward per episode: 289.45
# Num timesteps: 797000
# Best mean reward: 326.01 - Last mean reward per episode: 309.95
# Num timesteps: 798000
# Best mean reward: 326.01 - Last mean reward per episode: 325.82
# Num timesteps: 799000
# Best mean reward: 326.01 - Last mean reward per episode: 317.70
# Num timesteps: 800000
# Best mean reward: 326.01 - Last mean reward per episode: 335.05
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 801000
# Best mean reward: 335.05 - Last mean reward per episode: 339.42
# Saving new best model to ./saved_models_cont_mult/PPO/best_model_PPO
# Num timesteps: 802000
# Best mean reward: 339.42 - Last mean reward per episode: 337.79
# Num timesteps: 803000
# Best mean reward: 339.42 - Last mean reward per episode: 310.80
# Num timesteps: 804000
# Best mean reward: 339.42 - Last mean reward per episode: 314.34
# Num timesteps: 805000
# Best mean reward: 339.42 - Last mean reward per episode: 317.99
# Num timesteps: 806000
# Best mean reward: 339.42 - Last mean reward per episode: 281.30
# Num timesteps: 807000
# Best mean reward: 339.42 - Last mean reward per episode: 262.25
# Num timesteps: 808000
# Best mean reward: 339.42 - Last mean reward per episode: 255.19
# Num timesteps: 809000
# Best mean reward: 339.42 - Last mean reward per episode: 247.80
# Num timesteps: 810000
# Best mean reward: 339.42 - Last mean reward per episode: 218.47
# Num timesteps: 811000
# Best mean reward: 339.42 - Last mean reward per episode: 210.57
# Num timesteps: 812000
# Best mean reward: 339.42 - Last mean reward per episode: 225.33
# Num timesteps: 813000
# Best mean reward: 339.42 - Last mean reward per episode: 235.86
# Num timesteps: 814000
# Best mean reward: 339.42 - Last mean reward per episode: 222.37
# Num timesteps: 815000
# Best mean reward: 339.42 - Last mean reward per episode: 235.82
# Num timesteps: 816000
# Best mean reward: 339.42 - Last mean reward per episode: 258.57
# Num timesteps: 817000
# Best mean reward: 339.42 - Last mean reward per episode: 291.32
# Num timesteps: 818000
# Best mean reward: 339.42 - Last mean reward per episode: 270.05

# %% [markdown]
# # Check tensorboard

# %%
# !tensorboard --logdir ./tensorboard_logs_cont_mult/

# %% [markdown]
# # Load and check the model

# %%
log_dir = './saved_models_cont_mult/PPO/'
env = CustomEnv(obstacle_turn = True, 
                vizualaze     = True, 
                Total_war     = True,
                head_velocity = 0.01,
                num_obs       = 5, 
                num_enemy     = 2, 
                size_obs = [30, 40],
                steps_limit    = 2000)

# %%
import matplotlib.pyplot as plt
import cv2

# %%
state = env.reset()
state = cv2.cvtColor(state['img'], cv2.COLOR_BGR2RGB)
cv2.imwrite('final_img.png', state)
# cv2.imwrite

# %%
state_,  reward, done, _ = env.step([0.5, 0.8])
state_ = cv2.cvtColor(state_['img'], cv2.COLOR_BGR2RGB)
cv2.imwrite('final_img.png', state_)

# %%
model = PPO.load(path=log_dir + 'best_model_PPOobs_and_2enemy', env=env)

# %%
env.render(model)

# %%
state = env.reset()
action = model.predict(state)
print(action[0][0])

# %%
velosities = []
state = env.reset()
action = model.predict(state)
for i in range(0, 100):
    state, reward, done, numstep = env.step(action[0])
    action = model.predict(state)
    velosities.append(action[0][0])
print(max(velosities), min(velosities))
